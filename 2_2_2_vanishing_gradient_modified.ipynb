# %% [markdown]
# <a href="https://colab.research.google.com/github/ffalo64/rabbit_challenge/blob/main/2_2_2_vanishing_gradient_modified.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 準備

# %% [markdown]
# ## Google Colab 用の処理
#
# 下記を実行します
# - ドライブのマウント
# - ノートブックファイルと同じフォルダへの移動
#
# Googleドライブのマイドライブ を基準に DNN_code/DNN_code_colab_day2 フォルダを置くことを仮定しています。必要に応じて，パスを変更してください．

# %%
# Google Colab での実行かを調べる
import sys
import os
ENV_COLAB = True  if 'google.colab' in sys.modules else False 

# google drive のマウント
if ENV_COLAB:
  from google.colab import drive 
  drive.mount('/content/drive')
  os.chdir('/content/drive/My Drive/DNN_code/DNN_code_colab_day2/notebook')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %%
import sys
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定

# %% [markdown]
# # vanishing gradient modified

# %% [markdown]
# ## multi layer network class

# %%
import numpy as np
from common import layers
from collections import OrderedDict
from common import functions
from data.mnist import load_mnist
import matplotlib.pyplot as plt


class MultiLayerNet:
    '''
    input_size: 入力層のノード数
    hidden_size_list: 隠れ層のノード数のリスト
    output_size: 出力層のノード数
    activation: 活性化関数
    weight_init_std: 重みの初期化方法
    '''
    def __init__(self, input_size, hidden_size_list, output_size, activation='relu', weight_init_std='relu'):
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size_list = hidden_size_list
        self.hidden_layer_num = len(hidden_size_list)
        self.params = {}

        # 重みの初期化
        self.__init_weight(weight_init_std)

        # レイヤの生成, sigmoidとreluのみ扱う
        activation_layer = {'sigmoid': layers.Sigmoid, 'relu': layers.Relu}
        self.layers = OrderedDict() # 追加した順番に格納
        for idx in range(1, self.hidden_layer_num+1):
            self.layers['Affine' + str(idx)] = layers.Affine(self.params['W' + str(idx)], self.params['b' + str(idx)])
            self.layers['Activation_function' + str(idx)] = activation_layer[activation]()

        idx = self.hidden_layer_num + 1
        self.layers['Affine' + str(idx)] = layers.Affine(self.params['W' + str(idx)], self.params['b' + str(idx)])

        self.last_layer = layers.SoftmaxWithLoss()

    def __init_weight(self, weight_init_std):
        all_size_list = [self.input_size] + self.hidden_size_list + [self.output_size]
        for idx in range(1, len(all_size_list)):
            scale = weight_init_std
            if str(weight_init_std).lower() in ('relu', 'he'):
                scale = np.sqrt(2.0 / all_size_list[idx - 1])
            elif str(weight_init_std).lower() in ('sigmoid', 'xavier'):
                scale = np.sqrt(1.0 / all_size_list[idx - 1])

            self.params['W' + str(idx)] = scale * np.random.randn(all_size_list[idx-1], all_size_list[idx])
            self.params['b' + str(idx)] = np.zeros(all_size_list[idx])

    def predict(self, x):
        for layer in self.layers.values():
            x = layer.forward(x)

        return x

    def loss(self, x, d):
        y = self.predict(x)

        weight_decay = 0
        for idx in range(1, self.hidden_layer_num + 2):
            W = self.params['W' + str(idx)]

        return self.last_layer.forward(y, d) + weight_decay

    def accuracy(self, x, d):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        if d.ndim != 1 : d = np.argmax(d, axis=1)

        accuracy = np.sum(y == d) / float(x.shape[0])
        return accuracy

    def gradient(self, x, d):
        # forward
        self.loss(x, d)

        # backward
        dout = 1
        dout = self.last_layer.backward(dout)

        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)

        # 設定
        grad = {}
        for idx in range(1, self.hidden_layer_num+2):
            grad['W' + str(idx)] = self.layers['Affine' + str(idx)].dW
            grad['b' + str(idx)] = self.layers['Affine' + str(idx)].db

        return grad

# %% [markdown]
# ## vanishing sample
# ## sigmoid - gauss

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01)

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# Downloading train-images-idx3-ubyte.gz ...
# Done
# Downloading train-labels-idx1-ubyte.gz ...
# Done
# Downloading t10k-images-idx3-ubyte.gz ...
# Done
# Downloading t10k-labels-idx1-ubyte.gz ...
# Done
# Converting train-images-idx3-ubyte.gz to NumPy Array ...
# Done
# Converting train-labels-idx1-ubyte.gz to NumPy Array ...
# Done
# Converting t10k-images-idx3-ubyte.gz to NumPy Array ...
# Done
# Converting t10k-labels-idx1-ubyte.gz to NumPy Array ...
# Done
# Creating pickle file ...
# Done!
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.11
#                 : 10. 正答率(テスト) = 0.1135
# Generation: 20. 正答率(トレーニング) = 0.13
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.08
#                 : 30. 正答率(テスト) = 0.1028
# Generation: 40. 正答率(トレーニング) = 0.15
#                 : 40. 正答率(テスト) = 0.0974
# Generation: 50. 正答率(トレーニング) = 0.12
#                 : 50. 正答率(テスト) = 0.1028
# Generation: 60. 正答率(トレーニング) = 0.13
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.1
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.15
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.11
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.14
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.15
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.09
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.14
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.12
#                 : 140. 正答率(テスト) = 0.1028
# Generation: 150. 正答率(トレーニング) = 0.1
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.1
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.11
#                 : 170. 正答率(テスト) = 0.1028
# Generation: 180. 正答率(トレーニング) = 0.09
#                 : 180. 正答率(テスト) = 0.1028
# Generation: 190. 正答率(トレーニング) = 0.15
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.06
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.18
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.09
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.12
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.05
#                 : 240. 正答率(テスト) = 0.0958
# Generation: 250. 正答率(トレーニング) = 0.12
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.15
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.08
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.14
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.12
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.12
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.11
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.12
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.18
#                 : 330. 正答率(テスト) = 0.1028
# Generation: 340. 正答率(トレーニング) = 0.09
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.13
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.12
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.1
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.12
#                 : 380. 正答率(テスト) = 0.1032
# Generation: 390. 正答率(トレーニング) = 0.17
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.09
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.11
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.11
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.1
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.1
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.08
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.15
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.17
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.12
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.15
#                 : 490. 正答率(テスト) = 0.1028
# Generation: 500. 正答率(トレーニング) = 0.08
#                 : 500. 正答率(テスト) = 0.1028
# Generation: 510. 正答率(トレーニング) = 0.12
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.14
#                 : 520. 正答率(テスト) = 0.1028
# Generation: 530. 正答率(トレーニング) = 0.17
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.12
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.07
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.11
#                 : 560. 正答率(テスト) = 0.1135
# Generation: 570. 正答率(トレーニング) = 0.15
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.14
#                 : 580. 正答率(テスト) = 0.1135
# Generation: 590. 正答率(トレーニング) = 0.12
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.15
#                 : 600. 正答率(テスト) = 0.1135
# Generation: 610. 正答率(トレーニング) = 0.12
#                 : 610. 正答率(テスト) = 0.1135
# Generation: 620. 正答率(トレーニング) = 0.09
#                 : 620. 正答率(テスト) = 0.1135
# Generation: 630. 正答率(トレーニング) = 0.09
#                 : 630. 正答率(テスト) = 0.1028
# Generation: 640. 正答率(トレーニング) = 0.06
#                 : 640. 正答率(テスト) = 0.1009
# Generation: 650. 正答率(トレーニング) = 0.08
#                 : 650. 正答率(テスト) = 0.1028
# Generation: 660. 正答率(トレーニング) = 0.09
#                 : 660. 正答率(テスト) = 0.1028
# Generation: 670. 正答率(トレーニング) = 0.15
#                 : 670. 正答率(テスト) = 0.1028
# Generation: 680. 正答率(トレーニング) = 0.06
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.09
#                 : 690. 正答率(テスト) = 0.1135
# Generation: 700. 正答率(トレーニング) = 0.07
#                 : 700. 正答率(テスト) = 0.1135
# Generation: 710. 正答率(トレーニング) = 0.16
#                 : 710. 正答率(テスト) = 0.1032
# Generation: 720. 正答率(トレーニング) = 0.13
#                 : 720. 正答率(テスト) = 0.1135
# Generation: 730. 正答率(トレーニング) = 0.05
#                 : 730. 正答率(テスト) = 0.1135
# Generation: 740. 正答率(トレーニング) = 0.09
#                 : 740. 正答率(テスト) = 0.1135
# Generation: 750. 正答率(トレーニング) = 0.12
#                 : 750. 正答率(テスト) = 0.1135
# Generation: 760. 正答率(トレーニング) = 0.08
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.1
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.12
#                 : 780. 正答率(テスト) = 0.101
# Generation: 790. 正答率(トレーニング) = 0.15
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.13
#                 : 800. 正答率(テスト) = 0.1009
# Generation: 810. 正答率(トレーニング) = 0.08
#                 : 810. 正答率(テスト) = 0.1135
# Generation: 820. 正答率(トレーニング) = 0.18
#                 : 820. 正答率(テスト) = 0.1028
# Generation: 830. 正答率(トレーニング) = 0.08
#                 : 830. 正答率(テスト) = 0.101
# Generation: 840. 正答率(トレーニング) = 0.14
#                 : 840. 正答率(テスト) = 0.098
# Generation: 850. 正答率(トレーニング) = 0.13
#                 : 850. 正答率(テスト) = 0.098
# Generation: 860. 正答率(トレーニング) = 0.09
#                 : 860. 正答率(テスト) = 0.101
# Generation: 870. 正答率(トレーニング) = 0.15
#                 : 870. 正答率(テスト) = 0.101
# Generation: 880. 正答率(トレーニング) = 0.07
#                 : 880. 正答率(テスト) = 0.101
# Generation: 890. 正答率(トレーニング) = 0.09
#                 : 890. 正答率(テスト) = 0.1032
# Generation: 900. 正答率(トレーニング) = 0.07
#                 : 900. 正答率(テスト) = 0.1135
# Generation: 910. 正答率(トレーニング) = 0.1
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.12
#                 : 920. 正答率(テスト) = 0.101
# Generation: 930. 正答率(トレーニング) = 0.11
#                 : 930. 正答率(テスト) = 0.0958
# Generation: 940. 正答率(トレーニング) = 0.15
#                 : 940. 正答率(テスト) = 0.1028
# Generation: 950. 正答率(トレーニング) = 0.1
#                 : 950. 正答率(テスト) = 0.1135
# Generation: 960. 正答率(トレーニング) = 0.07
#                 : 960. 正答率(テスト) = 0.1135
# Generation: 970. 正答率(トレーニング) = 0.07
#                 : 970. 正答率(テスト) = 0.1135
# Generation: 980. 正答率(トレーニング) = 0.13
#                 : 980. 正答率(テスト) = 0.1135
# Generation: 990. 正答率(トレーニング) = 0.07
#                 : 990. 正答率(テスト) = 0.1135
# Generation: 1000. 正答率(トレーニング) = 0.15
#                 : 1000. 正答率(テスト) = 0.1135
# Generation: 1010. 正答率(トレーニング) = 0.15
#                 : 1010. 正答率(テスト) = 0.1135
# Generation: 1020. 正答率(トレーニング) = 0.14
#                 : 1020. 正答率(テスト) = 0.1135
# Generation: 1030. 正答率(トレーニング) = 0.15
#                 : 1030. 正答率(テスト) = 0.1135
# Generation: 1040. 正答率(トレーニング) = 0.13
#                 : 1040. 正答率(テスト) = 0.1135
# Generation: 1050. 正答率(トレーニング) = 0.09
#                 : 1050. 正答率(テスト) = 0.1135
# Generation: 1060. 正答率(トレーニング) = 0.1
#                 : 1060. 正答率(テスト) = 0.1135
# Generation: 1070. 正答率(トレーニング) = 0.15
#                 : 1070. 正答率(テスト) = 0.1135
# Generation: 1080. 正答率(トレーニング) = 0.11
#                 : 1080. 正答率(テスト) = 0.1135
# Generation: 1090. 正答率(トレーニング) = 0.16
#                 : 1090. 正答率(テスト) = 0.1135
# Generation: 1100. 正答率(トレーニング) = 0.09
#                 : 1100. 正答率(テスト) = 0.1135
# Generation: 1110. 正答率(トレーニング) = 0.07
#                 : 1110. 正答率(テスト) = 0.1135
# Generation: 1120. 正答率(トレーニング) = 0.09
#                 : 1120. 正答率(テスト) = 0.1135
# Generation: 1130. 正答率(トレーニング) = 0.1
#                 : 1130. 正答率(テスト) = 0.1028
# Generation: 1140. 正答率(トレーニング) = 0.14
#                 : 1140. 正答率(テスト) = 0.1135
# Generation: 1150. 正答率(トレーニング) = 0.11
#                 : 1150. 正答率(テスト) = 0.1135
# Generation: 1160. 正答率(トレーニング) = 0.14
#                 : 1160. 正答率(テスト) = 0.0958
# Generation: 1170. 正答率(トレーニング) = 0.08
#                 : 1170. 正答率(テスト) = 0.1028
# Generation: 1180. 正答率(トレーニング) = 0.11
#                 : 1180. 正答率(テスト) = 0.1135
# Generation: 1190. 正答率(トレーニング) = 0.07
#                 : 1190. 正答率(テスト) = 0.1135
# Generation: 1200. 正答率(トレーニング) = 0.11
#                 : 1200. 正答率(テスト) = 0.1135
# Generation: 1210. 正答率(トレーニング) = 0.14
#                 : 1210. 正答率(テスト) = 0.1135
# Generation: 1220. 正答率(トレーニング) = 0.11
#                 : 1220. 正答率(テスト) = 0.0974
# Generation: 1230. 正答率(トレーニング) = 0.11
#                 : 1230. 正答率(テスト) = 0.0974
# Generation: 1240. 正答率(トレーニング) = 0.12
#                 : 1240. 正答率(テスト) = 0.0958
# Generation: 1250. 正答率(トレーニング) = 0.09
#                 : 1250. 正答率(テスト) = 0.1135
# Generation: 1260. 正答率(トレーニング) = 0.12
#                 : 1260. 正答率(テスト) = 0.1028
# Generation: 1270. 正答率(トレーニング) = 0.1
#                 : 1270. 正答率(テスト) = 0.1135
# Generation: 1280. 正答率(トレーニング) = 0.14
#                 : 1280. 正答率(テスト) = 0.1135
# Generation: 1290. 正答率(トレーニング) = 0.05
#                 : 1290. 正答率(テスト) = 0.1028
# Generation: 1300. 正答率(トレーニング) = 0.13
#                 : 1300. 正答率(テスト) = 0.1028
# Generation: 1310. 正答率(トレーニング) = 0.15
#                 : 1310. 正答率(テスト) = 0.1135
# Generation: 1320. 正答率(トレーニング) = 0.07
#                 : 1320. 正答率(テスト) = 0.1135
# Generation: 1330. 正答率(トレーニング) = 0.09
#                 : 1330. 正答率(テスト) = 0.098
# Generation: 1340. 正答率(トレーニング) = 0.12
#                 : 1340. 正答率(テスト) = 0.1135
# Generation: 1350. 正答率(トレーニング) = 0.12
#                 : 1350. 正答率(テスト) = 0.1135
# Generation: 1360. 正答率(トレーニング) = 0.1
#                 : 1360. 正答率(テスト) = 0.1135
# Generation: 1370. 正答率(トレーニング) = 0.1
#                 : 1370. 正答率(テスト) = 0.1135
# Generation: 1380. 正答率(トレーニング) = 0.1
#                 : 1380. 正答率(テスト) = 0.1135
# Generation: 1390. 正答率(トレーニング) = 0.15
#                 : 1390. 正答率(テスト) = 0.1135
# Generation: 1400. 正答率(トレーニング) = 0.1
#                 : 1400. 正答率(テスト) = 0.1135
# Generation: 1410. 正答率(トレーニング) = 0.13
#                 : 1410. 正答率(テスト) = 0.1028
# Generation: 1420. 正答率(トレーニング) = 0.07
#                 : 1420. 正答率(テスト) = 0.1135
# Generation: 1430. 正答率(トレーニング) = 0.2
#                 : 1430. 正答率(テスト) = 0.1135
# Generation: 1440. 正答率(トレーニング) = 0.08
#                 : 1440. 正答率(テスト) = 0.1135
# Generation: 1450. 正答率(トレーニング) = 0.1
#                 : 1450. 正答率(テスト) = 0.1135
# Generation: 1460. 正答率(トレーニング) = 0.14
#                 : 1460. 正答率(テスト) = 0.1135
# Generation: 1470. 正答率(トレーニング) = 0.13
#                 : 1470. 正答率(テスト) = 0.1135
# Generation: 1480. 正答率(トレーニング) = 0.09
#                 : 1480. 正答率(テスト) = 0.1135
# Generation: 1490. 正答率(トレーニング) = 0.12
#                 : 1490. 正答率(テスト) = 0.1135
# Generation: 1500. 正答率(トレーニング) = 0.08
#                 : 1500. 正答率(テスト) = 0.1135
# Generation: 1510. 正答率(トレーニング) = 0.15
#                 : 1510. 正答率(テスト) = 0.1028
# Generation: 1520. 正答率(トレーニング) = 0.12
#                 : 1520. 正答率(テスト) = 0.1009
# Generation: 1530. 正答率(トレーニング) = 0.19
#                 : 1530. 正答率(テスト) = 0.1032
# Generation: 1540. 正答率(トレーニング) = 0.09
#                 : 1540. 正答率(テスト) = 0.1028
# Generation: 1550. 正答率(トレーニング) = 0.13
#                 : 1550. 正答率(テスト) = 0.1135
# Generation: 1560. 正答率(トレーニング) = 0.13
#                 : 1560. 正答率(テスト) = 0.1135
# Generation: 1570. 正答率(トレーニング) = 0.16
#                 : 1570. 正答率(テスト) = 0.1135
# Generation: 1580. 正答率(トレーニング) = 0.07
#                 : 1580. 正答率(テスト) = 0.1135
# Generation: 1590. 正答率(トレーニング) = 0.11
#                 : 1590. 正答率(テスト) = 0.1009
# Generation: 1600. 正答率(トレーニング) = 0.11
#                 : 1600. 正答率(テスト) = 0.1032
# Generation: 1610. 正答率(トレーニング) = 0.16
#                 : 1610. 正答率(テスト) = 0.098
# Generation: 1620. 正答率(トレーニング) = 0.07
#                 : 1620. 正答率(テスト) = 0.1028
# Generation: 1630. 正答率(トレーニング) = 0.14
#                 : 1630. 正答率(テスト) = 0.1028
# Generation: 1640. 正答率(トレーニング) = 0.08
#                 : 1640. 正答率(テスト) = 0.1135
# Generation: 1650. 正答率(トレーニング) = 0.16
#                 : 1650. 正答率(テスト) = 0.101
# Generation: 1660. 正答率(トレーニング) = 0.1
#                 : 1660. 正答率(テスト) = 0.1028
# Generation: 1670. 正答率(トレーニング) = 0.16
#                 : 1670. 正答率(テスト) = 0.101
# Generation: 1680. 正答率(トレーニング) = 0.17
#                 : 1680. 正答率(テスト) = 0.1135
# Generation: 1690. 正答率(トレーニング) = 0.09
#                 : 1690. 正答率(テスト) = 0.1135
# Generation: 1700. 正答率(トレーニング) = 0.14
#                 : 1700. 正答率(テスト) = 0.0982
# Generation: 1710. 正答率(トレーニング) = 0.1
#                 : 1710. 正答率(テスト) = 0.1028
# Generation: 1720. 正答率(トレーニング) = 0.11
#                 : 1720. 正答率(テスト) = 0.1135
# Generation: 1730. 正答率(トレーニング) = 0.1
#                 : 1730. 正答率(テスト) = 0.1032
# Generation: 1740. 正答率(トレーニング) = 0.15
#                 : 1740. 正答率(テスト) = 0.1028
# Generation: 1750. 正答率(トレーニング) = 0.09
#                 : 1750. 正答率(テスト) = 0.1028
# Generation: 1760. 正答率(トレーニング) = 0.12
#                 : 1760. 正答率(テスト) = 0.1028
# Generation: 1770. 正答率(トレーニング) = 0.12
#                 : 1770. 正答率(テスト) = 0.101
# Generation: 1780. 正答率(トレーニング) = 0.13
#                 : 1780. 正答率(テスト) = 0.1032
# Generation: 1790. 正答率(トレーニング) = 0.11
#                 : 1790. 正答率(テスト) = 0.1032
# Generation: 1800. 正答率(トレーニング) = 0.09
#                 : 1800. 正答率(テスト) = 0.1135
# Generation: 1810. 正答率(トレーニング) = 0.13
#                 : 1810. 正答率(テスト) = 0.1135
# Generation: 1820. 正答率(トレーニング) = 0.12
#                 : 1820. 正答率(テスト) = 0.1135
# Generation: 1830. 正答率(トレーニング) = 0.07
#                 : 1830. 正答率(テスト) = 0.1135
# Generation: 1840. 正答率(トレーニング) = 0.12
#                 : 1840. 正答率(テスト) = 0.1135
# Generation: 1850. 正答率(トレーニング) = 0.11
#                 : 1850. 正答率(テスト) = 0.1135
# Generation: 1860. 正答率(トレーニング) = 0.11
#                 : 1860. 正答率(テスト) = 0.1135
# Generation: 1870. 正答率(トレーニング) = 0.08
#                 : 1870. 正答率(テスト) = 0.0958
# Generation: 1880. 正答率(トレーニング) = 0.1
#                 : 1880. 正答率(テスト) = 0.1135
# Generation: 1890. 正答率(トレーニング) = 0.09
#                 : 1890. 正答率(テスト) = 0.1135
# Generation: 1900. 正答率(トレーニング) = 0.1
#                 : 1900. 正答率(テスト) = 0.098
# Generation: 1910. 正答率(トレーニング) = 0.1
#                 : 1910. 正答率(テスト) = 0.1135
# Generation: 1920. 正答率(トレーニング) = 0.04
#                 : 1920. 正答率(テスト) = 0.101
# Generation: 1930. 正答率(トレーニング) = 0.16
#                 : 1930. 正答率(テスト) = 0.1135
# Generation: 1940. 正答率(トレーニング) = 0.1
#                 : 1940. 正答率(テスト) = 0.1135
# Generation: 1950. 正答率(トレーニング) = 0.15
#                 : 1950. 正答率(テスト) = 0.1135
# Generation: 1960. 正答率(トレーニング) = 0.2
#                 : 1960. 正答率(テスト) = 0.1135
# Generation: 1970. 正答率(トレーニング) = 0.2
#                 : 1970. 正答率(テスト) = 0.1032
# Generation: 1980. 正答率(トレーニング) = 0.08
#                 : 1980. 正答率(テスト) = 0.1135
# Generation: 1990. 正答率(トレーニング) = 0.1
#                 : 1990. 正答率(テスト) = 0.1135
# Generation: 2000. 正答率(トレーニング) = 0.14
#                 : 2000. 正答率(テスト) = 0.1135

# %% [markdown]
# ## ReLU - gauss

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='relu', weight_init_std=0.01)

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.09
#                 : 10. 正答率(テスト) = 0.1135
# Generation: 20. 正答率(トレーニング) = 0.11
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.17
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.14
#                 : 40. 正答率(テスト) = 0.1135
# Generation: 50. 正答率(トレーニング) = 0.12
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.07
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.2
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.18
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.06
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.15
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.1
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.15
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.05
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.15
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.1
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.13
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.14
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.14
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.14
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.07
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.13
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.11
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.18
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.1
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.1
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.2
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.12
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.1
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.12
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.03
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.07
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.14
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.11
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.14
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.15
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.14
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.14
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.13
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.09
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.06
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.06
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.07
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.14
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.07
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.09
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.2
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.07
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.21
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.07
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.12
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.18
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.13
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.15
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.13
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.12
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.11
#                 : 560. 正答率(テスト) = 0.1135
# Generation: 570. 正答率(トレーニング) = 0.13
#                 : 570. 正答率(テスト) = 0.1141
# Generation: 580. 正答率(トレーニング) = 0.1
#                 : 580. 正答率(テスト) = 0.126
# Generation: 590. 正答率(トレーニング) = 0.16
#                 : 590. 正答率(テスト) = 0.1878
# Generation: 600. 正答率(トレーニング) = 0.24
#                 : 600. 正答率(テスト) = 0.235
# Generation: 610. 正答率(トレーニング) = 0.24
#                 : 610. 正答率(テスト) = 0.217
# Generation: 620. 正答率(トレーニング) = 0.25
#                 : 620. 正答率(テスト) = 0.2089
# Generation: 630. 正答率(トレーニング) = 0.13
#                 : 630. 正答率(テスト) = 0.2086
# Generation: 640. 正答率(トレーニング) = 0.28
#                 : 640. 正答率(テスト) = 0.2091
# Generation: 650. 正答率(トレーニング) = 0.14
#                 : 650. 正答率(テスト) = 0.2115
# Generation: 660. 正答率(トレーニング) = 0.15
#                 : 660. 正答率(テスト) = 0.2202
# Generation: 670. 正答率(トレーニング) = 0.23
#                 : 670. 正答率(テスト) = 0.224
# Generation: 680. 正答率(トレーニング) = 0.28
#                 : 680. 正答率(テスト) = 0.2592
# Generation: 690. 正答率(トレーニング) = 0.29
#                 : 690. 正答率(テスト) = 0.2873
# Generation: 700. 正答率(トレーニング) = 0.41
#                 : 700. 正答率(テスト) = 0.3708
# Generation: 710. 正答率(トレーニング) = 0.31
#                 : 710. 正答率(テスト) = 0.331
# Generation: 720. 正答率(トレーニング) = 0.35
#                 : 720. 正答率(テスト) = 0.3934
# Generation: 730. 正答率(トレーニング) = 0.38
#                 : 730. 正答率(テスト) = 0.3928
# Generation: 740. 正答率(トレーニング) = 0.48
#                 : 740. 正答率(テスト) = 0.3993
# Generation: 750. 正答率(トレーニング) = 0.43
#                 : 750. 正答率(テスト) = 0.432
# Generation: 760. 正答率(トレーニング) = 0.52
#                 : 760. 正答率(テスト) = 0.4273
# Generation: 770. 正答率(トレーニング) = 0.53
#                 : 770. 正答率(テスト) = 0.4767
# Generation: 780. 正答率(トレーニング) = 0.51
#                 : 780. 正答率(テスト) = 0.4965
# Generation: 790. 正答率(トレーニング) = 0.52
#                 : 790. 正答率(テスト) = 0.5308
# Generation: 800. 正答率(トレーニング) = 0.6
#                 : 800. 正答率(テスト) = 0.488
# Generation: 810. 正答率(トレーニング) = 0.56
#                 : 810. 正答率(テスト) = 0.5515
# Generation: 820. 正答率(トレーニング) = 0.71
#                 : 820. 正答率(テスト) = 0.5511
# Generation: 830. 正答率(トレーニング) = 0.65
#                 : 830. 正答率(テスト) = 0.562
# Generation: 840. 正答率(トレーニング) = 0.63
#                 : 840. 正答率(テスト) = 0.5223
# Generation: 850. 正答率(トレーニング) = 0.64
#                 : 850. 正答率(テスト) = 0.6085
# Generation: 860. 正答率(トレーニング) = 0.64
#                 : 860. 正答率(テスト) = 0.6277
# Generation: 870. 正答率(トレーニング) = 0.66
#                 : 870. 正答率(テスト) = 0.6166
# Generation: 880. 正答率(トレーニング) = 0.59
#                 : 880. 正答率(テスト) = 0.6173
# Generation: 890. 正答率(トレーニング) = 0.58
#                 : 890. 正答率(テスト) = 0.5701
# Generation: 900. 正答率(トレーニング) = 0.63
#                 : 900. 正答率(テスト) = 0.6251
# Generation: 910. 正答率(トレーニング) = 0.73
#                 : 910. 正答率(テスト) = 0.6519
# Generation: 920. 正答率(トレーニング) = 0.62
#                 : 920. 正答率(テスト) = 0.6581
# Generation: 930. 正答率(トレーニング) = 0.69
#                 : 930. 正答率(テスト) = 0.615
# Generation: 940. 正答率(トレーニング) = 0.64
#                 : 940. 正答率(テスト) = 0.6558
# Generation: 950. 正答率(トレーニング) = 0.62
#                 : 950. 正答率(テスト) = 0.6772
# Generation: 960. 正答率(トレーニング) = 0.74
#                 : 960. 正答率(テスト) = 0.6445
# Generation: 970. 正答率(トレーニング) = 0.71
#                 : 970. 正答率(テスト) = 0.6875
# Generation: 980. 正答率(トレーニング) = 0.72
#                 : 980. 正答率(テスト) = 0.6709
# Generation: 990. 正答率(トレーニング) = 0.73
#                 : 990. 正答率(テスト) = 0.6789
# Generation: 1000. 正答率(トレーニング) = 0.7
#                 : 1000. 正答率(テスト) = 0.7241
# Generation: 1010. 正答率(トレーニング) = 0.67
#                 : 1010. 正答率(テスト) = 0.6323
# Generation: 1020. 正答率(トレーニング) = 0.76
#                 : 1020. 正答率(テスト) = 0.6993
# Generation: 1030. 正答率(トレーニング) = 0.82
#                 : 1030. 正答率(テスト) = 0.7455
# Generation: 1040. 正答率(トレーニング) = 0.65
#                 : 1040. 正答率(テスト) = 0.7212
# Generation: 1050. 正答率(トレーニング) = 0.74
#                 : 1050. 正答率(テスト) = 0.7232
# Generation: 1060. 正答率(トレーニング) = 0.79
#                 : 1060. 正答率(テスト) = 0.7227
# Generation: 1070. 正答率(トレーニング) = 0.84
#                 : 1070. 正答率(テスト) = 0.7329
# Generation: 1080. 正答率(トレーニング) = 0.79
#                 : 1080. 正答率(テスト) = 0.7437
# Generation: 1090. 正答率(トレーニング) = 0.74
#                 : 1090. 正答率(テスト) = 0.7481
# Generation: 1100. 正答率(トレーニング) = 0.84
#                 : 1100. 正答率(テスト) = 0.8148
# Generation: 1110. 正答率(トレーニング) = 0.79
#                 : 1110. 正答率(テスト) = 0.7692
# Generation: 1120. 正答率(トレーニング) = 0.8
#                 : 1120. 正答率(テスト) = 0.8121
# Generation: 1130. 正答率(トレーニング) = 0.91
#                 : 1130. 正答率(テスト) = 0.8252
# Generation: 1140. 正答率(トレーニング) = 0.83
#                 : 1140. 正答率(テスト) = 0.8289
# Generation: 1150. 正答率(トレーニング) = 0.82
#                 : 1150. 正答率(テスト) = 0.8241
# Generation: 1160. 正答率(トレーニング) = 0.88
#                 : 1160. 正答率(テスト) = 0.7753
# Generation: 1170. 正答率(トレーニング) = 0.82
#                 : 1170. 正答率(テスト) = 0.8326
# Generation: 1180. 正答率(トレーニング) = 0.85
#                 : 1180. 正答率(テスト) = 0.8335
# Generation: 1190. 正答率(トレーニング) = 0.87
#                 : 1190. 正答率(テスト) = 0.8323
# Generation: 1200. 正答率(トレーニング) = 0.82
#                 : 1200. 正答率(テスト) = 0.8369
# Generation: 1210. 正答率(トレーニング) = 0.93
#                 : 1210. 正答率(テスト) = 0.8325
# Generation: 1220. 正答率(トレーニング) = 0.91
#                 : 1220. 正答率(テスト) = 0.8409
# Generation: 1230. 正答率(トレーニング) = 0.84
#                 : 1230. 正答率(テスト) = 0.8349
# Generation: 1240. 正答率(トレーニング) = 0.87
#                 : 1240. 正答率(テスト) = 0.8406
# Generation: 1250. 正答率(トレーニング) = 0.85
#                 : 1250. 正答率(テスト) = 0.8338
# Generation: 1260. 正答率(トレーニング) = 0.88
#                 : 1260. 正答率(テスト) = 0.8495
# Generation: 1270. 正答率(トレーニング) = 0.9
#                 : 1270. 正答率(テスト) = 0.8451
# Generation: 1280. 正答率(トレーニング) = 0.91
#                 : 1280. 正答率(テスト) = 0.8289
# Generation: 1290. 正答率(トレーニング) = 0.84
#                 : 1290. 正答率(テスト) = 0.8152
# Generation: 1300. 正答率(トレーニング) = 0.91
#                 : 1300. 正答率(テスト) = 0.8497
# Generation: 1310. 正答率(トレーニング) = 0.85
#                 : 1310. 正答率(テスト) = 0.8367
# Generation: 1320. 正答率(トレーニング) = 0.92
#                 : 1320. 正答率(テスト) = 0.8513
# Generation: 1330. 正答率(トレーニング) = 0.87
#                 : 1330. 正答率(テスト) = 0.8576
# Generation: 1340. 正答率(トレーニング) = 0.86
#                 : 1340. 正答率(テスト) = 0.8459
# Generation: 1350. 正答率(トレーニング) = 0.87
#                 : 1350. 正答率(テスト) = 0.8484
# Generation: 1360. 正答率(トレーニング) = 0.88
#                 : 1360. 正答率(テスト) = 0.8485
# Generation: 1370. 正答率(トレーニング) = 0.82
#                 : 1370. 正答率(テスト) = 0.8367
# Generation: 1380. 正答率(トレーニング) = 0.82
#                 : 1380. 正答率(テスト) = 0.8504
# Generation: 1390. 正答率(トレーニング) = 0.87
#                 : 1390. 正答率(テスト) = 0.8543
# Generation: 1400. 正答率(トレーニング) = 0.8
#                 : 1400. 正答率(テスト) = 0.859
# Generation: 1410. 正答率(トレーニング) = 0.94
#                 : 1410. 正答率(テスト) = 0.8556
# Generation: 1420. 正答率(トレーニング) = 0.78
#                 : 1420. 正答率(テスト) = 0.8626
# Generation: 1430. 正答率(トレーニング) = 0.88
#                 : 1430. 正答率(テスト) = 0.8461
# Generation: 1440. 正答率(トレーニング) = 0.89
#                 : 1440. 正答率(テスト) = 0.8621
# Generation: 1450. 正答率(トレーニング) = 0.94
#                 : 1450. 正答率(テスト) = 0.8655
# Generation: 1460. 正答率(トレーニング) = 0.89
#                 : 1460. 正答率(テスト) = 0.8631
# Generation: 1470. 正答率(トレーニング) = 0.9
#                 : 1470. 正答率(テスト) = 0.8685
# Generation: 1480. 正答率(トレーニング) = 0.89
#                 : 1480. 正答率(テスト) = 0.8706
# Generation: 1490. 正答率(トレーニング) = 0.93
#                 : 1490. 正答率(テスト) = 0.8661
# Generation: 1500. 正答率(トレーニング) = 0.92
#                 : 1500. 正答率(テスト) = 0.8652
# Generation: 1510. 正答率(トレーニング) = 0.93
#                 : 1510. 正答率(テスト) = 0.8651
# Generation: 1520. 正答率(トレーニング) = 0.89
#                 : 1520. 正答率(テスト) = 0.8621
# Generation: 1530. 正答率(トレーニング) = 0.85
#                 : 1530. 正答率(テスト) = 0.8671
# Generation: 1540. 正答率(トレーニング) = 0.91
#                 : 1540. 正答率(テスト) = 0.8725
# Generation: 1550. 正答率(トレーニング) = 0.83
#                 : 1550. 正答率(テスト) = 0.8642
# Generation: 1560. 正答率(トレーニング) = 0.94
#                 : 1560. 正答率(テスト) = 0.8756
# Generation: 1570. 正答率(トレーニング) = 0.93
#                 : 1570. 正答率(テスト) = 0.8732
# Generation: 1580. 正答率(トレーニング) = 0.86
#                 : 1580. 正答率(テスト) = 0.8772
# Generation: 1590. 正答率(トレーニング) = 0.87
#                 : 1590. 正答率(テスト) = 0.8743
# Generation: 1600. 正答率(トレーニング) = 0.87
#                 : 1600. 正答率(テスト) = 0.8757
# Generation: 1610. 正答率(トレーニング) = 0.93
#                 : 1610. 正答率(テスト) = 0.8819
# Generation: 1620. 正答率(トレーニング) = 0.9
#                 : 1620. 正答率(テスト) = 0.8749
# Generation: 1630. 正答率(トレーニング) = 0.9
#                 : 1630. 正答率(テスト) = 0.8808
# Generation: 1640. 正答率(トレーニング) = 0.92
#                 : 1640. 正答率(テスト) = 0.8893
# Generation: 1650. 正答率(トレーニング) = 0.94
#                 : 1650. 正答率(テスト) = 0.8855
# Generation: 1660. 正答率(トレーニング) = 0.91
#                 : 1660. 正答率(テスト) = 0.8939
# Generation: 1670. 正答率(トレーニング) = 0.9
#                 : 1670. 正答率(テスト) = 0.8931
# Generation: 1680. 正答率(トレーニング) = 0.93
#                 : 1680. 正答率(テスト) = 0.8883
# Generation: 1690. 正答率(トレーニング) = 0.93
#                 : 1690. 正答率(テスト) = 0.8839
# Generation: 1700. 正答率(トレーニング) = 0.93
#                 : 1700. 正答率(テスト) = 0.8901
# Generation: 1710. 正答率(トレーニング) = 0.9
#                 : 1710. 正答率(テスト) = 0.8868
# Generation: 1720. 正答率(トレーニング) = 0.9
#                 : 1720. 正答率(テスト) = 0.8856
# Generation: 1730. 正答率(トレーニング) = 0.92
#                 : 1730. 正答率(テスト) = 0.8876
# Generation: 1740. 正答率(トレーニング) = 0.93
#                 : 1740. 正答率(テスト) = 0.8955
# Generation: 1750. 正答率(トレーニング) = 0.9
#                 : 1750. 正答率(テスト) = 0.8989
# Generation: 1760. 正答率(トレーニング) = 0.94
#                 : 1760. 正答率(テスト) = 0.8967
# Generation: 1770. 正答率(トレーニング) = 0.89
#                 : 1770. 正答率(テスト) = 0.8945
# Generation: 1780. 正答率(トレーニング) = 0.95
#                 : 1780. 正答率(テスト) = 0.8979
# Generation: 1790. 正答率(トレーニング) = 0.93
#                 : 1790. 正答率(テスト) = 0.9025
# Generation: 1800. 正答率(トレーニング) = 0.95
#                 : 1800. 正答率(テスト) = 0.8992
# Generation: 1810. 正答率(トレーニング) = 0.96
#                 : 1810. 正答率(テスト) = 0.9019
# Generation: 1820. 正答率(トレーニング) = 0.9
#                 : 1820. 正答率(テスト) = 0.8948
# Generation: 1830. 正答率(トレーニング) = 0.9
#                 : 1830. 正答率(テスト) = 0.8971
# Generation: 1840. 正答率(トレーニング) = 0.93
#                 : 1840. 正答率(テスト) = 0.9064
# Generation: 1850. 正答率(トレーニング) = 0.97
#                 : 1850. 正答率(テスト) = 0.8997
# Generation: 1860. 正答率(トレーニング) = 0.9
#                 : 1860. 正答率(テスト) = 0.9012
# Generation: 1870. 正答率(トレーニング) = 0.89
#                 : 1870. 正答率(テスト) = 0.9043
# Generation: 1880. 正答率(トレーニング) = 0.91
#                 : 1880. 正答率(テスト) = 0.9
# Generation: 1890. 正答率(トレーニング) = 0.93
#                 : 1890. 正答率(テスト) = 0.9107
# Generation: 1900. 正答率(トレーニング) = 0.9
#                 : 1900. 正答率(テスト) = 0.9071
# Generation: 1910. 正答率(トレーニング) = 0.95
#                 : 1910. 正答率(テスト) = 0.908
# Generation: 1920. 正答率(トレーニング) = 0.94
#                 : 1920. 正答率(テスト) = 0.9122
# Generation: 1930. 正答率(トレーニング) = 0.96
#                 : 1930. 正答率(テスト) = 0.9106
# Generation: 1940. 正答率(トレーニング) = 0.97
#                 : 1940. 正答率(テスト) = 0.9088
# Generation: 1950. 正答率(トレーニング) = 0.91
#                 : 1950. 正答率(テスト) = 0.9077
# Generation: 1960. 正答率(トレーニング) = 0.92
#                 : 1960. 正答率(テスト) = 0.9123
# Generation: 1970. 正答率(トレーニング) = 0.92
#                 : 1970. 正答率(テスト) = 0.9116
# Generation: 1980. 正答率(トレーニング) = 0.91
#                 : 1980. 正答率(テスト) = 0.9091
# Generation: 1990. 正答率(トレーニング) = 0.94
#                 : 1990. 正答率(テスト) = 0.914
# Generation: 2000. 正答率(トレーニング) = 0.95
#                 : 2000. 正答率(テスト) = 0.9159

# %% [markdown]
# ## sigmoid - Xavier

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std='Xavier')

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()

# %% [markdown]
# ## ReLU - He

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='relu', weight_init_std='He')

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.49
#                 : 10. 正答率(テスト) = 0.427
# Generation: 20. 正答率(トレーニング) = 0.6
#                 : 20. 正答率(テスト) = 0.548
# Generation: 30. 正答率(トレーニング) = 0.8
#                 : 30. 正答率(テスト) = 0.7333
# Generation: 40. 正答率(トレーニング) = 0.77
#                 : 40. 正答率(テスト) = 0.783
# Generation: 50. 正答率(トレーニング) = 0.8
#                 : 50. 正答率(テスト) = 0.7301
# Generation: 60. 正答率(トレーニング) = 0.83
#                 : 60. 正答率(テスト) = 0.7929
# Generation: 70. 正答率(トレーニング) = 0.9
#                 : 70. 正答率(テスト) = 0.8446
# Generation: 80. 正答率(トレーニング) = 0.91
#                 : 80. 正答率(テスト) = 0.863
# Generation: 90. 正答率(トレーニング) = 0.91
#                 : 90. 正答率(テスト) = 0.8575
# Generation: 100. 正答率(トレーニング) = 0.92
#                 : 100. 正答率(テスト) = 0.867
# Generation: 110. 正答率(トレーニング) = 0.9
#                 : 110. 正答率(テスト) = 0.8663
# Generation: 120. 正答率(トレーニング) = 0.92
#                 : 120. 正答率(テスト) = 0.8681
# Generation: 130. 正答率(トレーニング) = 0.87
#                 : 130. 正答率(テスト) = 0.8161
# Generation: 140. 正答率(トレーニング) = 0.92
#                 : 140. 正答率(テスト) = 0.8696
# Generation: 150. 正答率(トレーニング) = 0.89
#                 : 150. 正答率(テスト) = 0.8488
# Generation: 160. 正答率(トレーニング) = 0.92
#                 : 160. 正答率(テスト) = 0.8846
# Generation: 170. 正答率(トレーニング) = 0.92
#                 : 170. 正答率(テスト) = 0.8899
# Generation: 180. 正答率(トレーニング) = 0.92
#                 : 180. 正答率(テスト) = 0.8899
# Generation: 190. 正答率(トレーニング) = 0.9
#                 : 190. 正答率(テスト) = 0.8812
# Generation: 200. 正答率(トレーニング) = 0.88
#                 : 200. 正答率(テスト) = 0.8964
# Generation: 210. 正答率(トレーニング) = 0.91
#                 : 210. 正答率(テスト) = 0.8982
# Generation: 220. 正答率(トレーニング) = 0.95
#                 : 220. 正答率(テスト) = 0.8969
# Generation: 230. 正答率(トレーニング) = 0.95
#                 : 230. 正答率(テスト) = 0.9005
# Generation: 240. 正答率(トレーニング) = 0.98
#                 : 240. 正答率(テスト) = 0.8927
# Generation: 250. 正答率(トレーニング) = 0.95
#                 : 250. 正答率(テスト) = 0.9053
# Generation: 260. 正答率(トレーニング) = 0.91
#                 : 260. 正答率(テスト) = 0.9013
# Generation: 270. 正答率(トレーニング) = 0.92
#                 : 270. 正答率(テスト) = 0.9016
# Generation: 280. 正答率(トレーニング) = 0.93
#                 : 280. 正答率(テスト) = 0.9102
# Generation: 290. 正答率(トレーニング) = 0.93
#                 : 290. 正答率(テスト) = 0.908
# Generation: 300. 正答率(トレーニング) = 0.98
#                 : 300. 正答率(テスト) = 0.9118
# Generation: 310. 正答率(トレーニング) = 0.91
#                 : 310. 正答率(テスト) = 0.9101
# Generation: 320. 正答率(トレーニング) = 0.98
#                 : 320. 正答率(テスト) = 0.903
# Generation: 330. 正答率(トレーニング) = 0.94
#                 : 330. 正答率(テスト) = 0.9133
# Generation: 340. 正答率(トレーニング) = 0.91
#                 : 340. 正答率(テスト) = 0.9116
# Generation: 350. 正答率(トレーニング) = 0.98
#                 : 350. 正答率(テスト) = 0.9166
# Generation: 360. 正答率(トレーニング) = 0.94
#                 : 360. 正答率(テスト) = 0.9178
# Generation: 370. 正答率(トレーニング) = 0.97
#                 : 370. 正答率(テスト) = 0.9143
# Generation: 380. 正答率(トレーニング) = 0.94
#                 : 380. 正答率(テスト) = 0.9127
# Generation: 390. 正答率(トレーニング) = 0.94
#                 : 390. 正答率(テスト) = 0.916
# Generation: 400. 正答率(トレーニング) = 0.91
#                 : 400. 正答率(テスト) = 0.9215
# Generation: 410. 正答率(トレーニング) = 0.97
#                 : 410. 正答率(テスト) = 0.9137
# Generation: 420. 正答率(トレーニング) = 0.93
#                 : 420. 正答率(テスト) = 0.9099
# Generation: 430. 正答率(トレーニング) = 0.96
#                 : 430. 正答率(テスト) = 0.9128
# Generation: 440. 正答率(トレーニング) = 0.92
#                 : 440. 正答率(テスト) = 0.9173
# Generation: 450. 正答率(トレーニング) = 0.96
#                 : 450. 正答率(テスト) = 0.9183
# Generation: 460. 正答率(トレーニング) = 0.92
#                 : 460. 正答率(テスト) = 0.9219
# Generation: 470. 正答率(トレーニング) = 0.95
#                 : 470. 正答率(テスト) = 0.9248
# Generation: 480. 正答率(トレーニング) = 0.96
#                 : 480. 正答率(テスト) = 0.9253
# Generation: 490. 正答率(トレーニング) = 0.96
#                 : 490. 正答率(テスト) = 0.9256
# Generation: 500. 正答率(トレーニング) = 0.95
#                 : 500. 正答率(テスト) = 0.9265
# Generation: 510. 正答率(トレーニング) = 0.98
#                 : 510. 正答率(テスト) = 0.9223
# Generation: 520. 正答率(トレーニング) = 0.96
#                 : 520. 正答率(テスト) = 0.9263
# Generation: 530. 正答率(トレーニング) = 0.96
#                 : 530. 正答率(テスト) = 0.9223
# Generation: 540. 正答率(トレーニング) = 0.97
#                 : 540. 正答率(テスト) = 0.9305
# Generation: 550. 正答率(トレーニング) = 0.95
#                 : 550. 正答率(テスト) = 0.9243
# Generation: 560. 正答率(トレーニング) = 0.97
#                 : 560. 正答率(テスト) = 0.9326
# Generation: 570. 正答率(トレーニング) = 0.97
#                 : 570. 正答率(テスト) = 0.9274
# Generation: 580. 正答率(トレーニング) = 0.95
#                 : 580. 正答率(テスト) = 0.9287
# Generation: 590. 正答率(トレーニング) = 1.0
#                 : 590. 正答率(テスト) = 0.9259
# Generation: 600. 正答率(トレーニング) = 0.95
#                 : 600. 正答率(テスト) = 0.9323
# Generation: 610. 正答率(トレーニング) = 0.97
#                 : 610. 正答率(テスト) = 0.93
# Generation: 620. 正答率(トレーニング) = 0.94
#                 : 620. 正答率(テスト) = 0.9309
# Generation: 630. 正答率(トレーニング) = 0.94
#                 : 630. 正答率(テスト) = 0.9307
# Generation: 640. 正答率(トレーニング) = 0.95
#                 : 640. 正答率(テスト) = 0.9336
# Generation: 650. 正答率(トレーニング) = 0.96
#                 : 650. 正答率(テスト) = 0.9322
# Generation: 660. 正答率(トレーニング) = 0.96
#                 : 660. 正答率(テスト) = 0.9289
# Generation: 670. 正答率(トレーニング) = 0.97
#                 : 670. 正答率(テスト) = 0.9357
# Generation: 680. 正答率(トレーニング) = 0.95
#                 : 680. 正答率(テスト) = 0.9216
# Generation: 690. 正答率(トレーニング) = 0.96
#                 : 690. 正答率(テスト) = 0.9255
# Generation: 700. 正答率(トレーニング) = 0.99
#                 : 700. 正答率(テスト) = 0.9341
# Generation: 710. 正答率(トレーニング) = 0.98
#                 : 710. 正答率(テスト) = 0.9337
# Generation: 720. 正答率(トレーニング) = 0.95
#                 : 720. 正答率(テスト) = 0.9354
# Generation: 730. 正答率(トレーニング) = 0.94
#                 : 730. 正答率(テスト) = 0.9373
# Generation: 740. 正答率(トレーニング) = 0.93
#                 : 740. 正答率(テスト) = 0.9369
# Generation: 750. 正答率(トレーニング) = 0.96
#                 : 750. 正答率(テスト) = 0.9369
# Generation: 760. 正答率(トレーニング) = 0.95
#                 : 760. 正答率(テスト) = 0.9345
# Generation: 770. 正答率(トレーニング) = 0.94
#                 : 770. 正答率(テスト) = 0.9337
# Generation: 780. 正答率(トレーニング) = 0.96
#                 : 780. 正答率(テスト) = 0.9356
# Generation: 790. 正答率(トレーニング) = 0.98
#                 : 790. 正答率(テスト) = 0.9326
# Generation: 800. 正答率(トレーニング) = 0.98
#                 : 800. 正答率(テスト) = 0.9384
# Generation: 810. 正答率(トレーニング) = 0.98
#                 : 810. 正答率(テスト) = 0.9358
# Generation: 820. 正答率(トレーニング) = 0.95
#                 : 820. 正答率(テスト) = 0.9353
# Generation: 830. 正答率(トレーニング) = 0.97
#                 : 830. 正答率(テスト) = 0.9364
# Generation: 840. 正答率(トレーニング) = 0.95
#                 : 840. 正答率(テスト) = 0.9399
# Generation: 850. 正答率(トレーニング) = 0.99
#                 : 850. 正答率(テスト) = 0.9388
# Generation: 860. 正答率(トレーニング) = 0.93
#                 : 860. 正答率(テスト) = 0.9381
# Generation: 870. 正答率(トレーニング) = 1.0
#                 : 870. 正答率(テスト) = 0.9328
# Generation: 880. 正答率(トレーニング) = 0.95
#                 : 880. 正答率(テスト) = 0.9378
# Generation: 890. 正答率(トレーニング) = 0.99
#                 : 890. 正答率(テスト) = 0.9367
# Generation: 900. 正答率(トレーニング) = 0.97
#                 : 900. 正答率(テスト) = 0.9395
# Generation: 910. 正答率(トレーニング) = 0.97
#                 : 910. 正答率(テスト) = 0.933
# Generation: 920. 正答率(トレーニング) = 0.97
#                 : 920. 正答率(テスト) = 0.9358
# Generation: 930. 正答率(トレーニング) = 0.95
#                 : 930. 正答率(テスト) = 0.9426
# Generation: 940. 正答率(トレーニング) = 0.97
#                 : 940. 正答率(テスト) = 0.9429
# Generation: 950. 正答率(トレーニング) = 0.92
#                 : 950. 正答率(テスト) = 0.9324
# Generation: 960. 正答率(トレーニング) = 0.94
#                 : 960. 正答率(テスト) = 0.9401
# Generation: 970. 正答率(トレーニング) = 0.97
#                 : 970. 正答率(テスト) = 0.9409
# Generation: 980. 正答率(トレーニング) = 0.97
#                 : 980. 正答率(テスト) = 0.9445
# Generation: 990. 正答率(トレーニング) = 0.94
#                 : 990. 正答率(テスト) = 0.9381
# Generation: 1000. 正答率(トレーニング) = 0.97
#                 : 1000. 正答率(テスト) = 0.9432
# Generation: 1010. 正答率(トレーニング) = 0.92
#                 : 1010. 正答率(テスト) = 0.9427
# Generation: 1020. 正答率(トレーニング) = 0.96
#                 : 1020. 正答率(テスト) = 0.9367
# Generation: 1030. 正答率(トレーニング) = 0.92
#                 : 1030. 正答率(テスト) = 0.9392
# Generation: 1040. 正答率(トレーニング) = 1.0
#                 : 1040. 正答率(テスト) = 0.9448
# Generation: 1050. 正答率(トレーニング) = 0.99
#                 : 1050. 正答率(テスト) = 0.947
# Generation: 1060. 正答率(トレーニング) = 0.96
#                 : 1060. 正答率(テスト) = 0.9395
# Generation: 1070. 正答率(トレーニング) = 0.94
#                 : 1070. 正答率(テスト) = 0.9405
# Generation: 1080. 正答率(トレーニング) = 0.96
#                 : 1080. 正答率(テスト) = 0.9434
# Generation: 1090. 正答率(トレーニング) = 0.94
#                 : 1090. 正答率(テスト) = 0.9436
# Generation: 1100. 正答率(トレーニング) = 0.95
#                 : 1100. 正答率(テスト) = 0.9355
# Generation: 1110. 正答率(トレーニング) = 0.97
#                 : 1110. 正答率(テスト) = 0.9468
# Generation: 1120. 正答率(トレーニング) = 0.98
#                 : 1120. 正答率(テスト) = 0.9457
# Generation: 1130. 正答率(トレーニング) = 0.97
#                 : 1130. 正答率(テスト) = 0.9472
# Generation: 1140. 正答率(トレーニング) = 0.99
#                 : 1140. 正答率(テスト) = 0.9439
# Generation: 1150. 正答率(トレーニング) = 0.97
#                 : 1150. 正答率(テスト) = 0.9489
# Generation: 1160. 正答率(トレーニング) = 0.98
#                 : 1160. 正答率(テスト) = 0.9495
# Generation: 1170. 正答率(トレーニング) = 0.98
#                 : 1170. 正答率(テスト) = 0.9448
# Generation: 1180. 正答率(トレーニング) = 0.97
#                 : 1180. 正答率(テスト) = 0.9386
# Generation: 1190. 正答率(トレーニング) = 0.97
#                 : 1190. 正答率(テスト) = 0.9489
# Generation: 1200. 正答率(トレーニング) = 0.99
#                 : 1200. 正答率(テスト) = 0.9472
# Generation: 1210. 正答率(トレーニング) = 1.0
#                 : 1210. 正答率(テスト) = 0.9422
# Generation: 1220. 正答率(トレーニング) = 0.97
#                 : 1220. 正答率(テスト) = 0.9447
# Generation: 1230. 正答率(トレーニング) = 0.99
#                 : 1230. 正答率(テスト) = 0.9488
# Generation: 1240. 正答率(トレーニング) = 1.0
#                 : 1240. 正答率(テスト) = 0.9482
# Generation: 1250. 正答率(トレーニング) = 0.99
#                 : 1250. 正答率(テスト) = 0.9484
# Generation: 1260. 正答率(トレーニング) = 1.0
#                 : 1260. 正答率(テスト) = 0.9494
# Generation: 1270. 正答率(トレーニング) = 0.94
#                 : 1270. 正答率(テスト) = 0.9445
# Generation: 1280. 正答率(トレーニング) = 0.95
#                 : 1280. 正答率(テスト) = 0.9489
# Generation: 1290. 正答率(トレーニング) = 0.99
#                 : 1290. 正答率(テスト) = 0.9474
# Generation: 1300. 正答率(トレーニング) = 0.98
#                 : 1300. 正答率(テスト) = 0.9491
# Generation: 1310. 正答率(トレーニング) = 0.97
#                 : 1310. 正答率(テスト) = 0.9492
# Generation: 1320. 正答率(トレーニング) = 0.96
#                 : 1320. 正答率(テスト) = 0.9409
# Generation: 1330. 正答率(トレーニング) = 0.99
#                 : 1330. 正答率(テスト) = 0.951
# Generation: 1340. 正答率(トレーニング) = 0.98
#                 : 1340. 正答率(テスト) = 0.9481
# Generation: 1350. 正答率(トレーニング) = 0.98
#                 : 1350. 正答率(テスト) = 0.9504
# Generation: 1360. 正答率(トレーニング) = 0.91
#                 : 1360. 正答率(テスト) = 0.9453
# Generation: 1370. 正答率(トレーニング) = 0.96
#                 : 1370. 正答率(テスト) = 0.9471
# Generation: 1380. 正答率(トレーニング) = 0.97
#                 : 1380. 正答率(テスト) = 0.9477
# Generation: 1390. 正答率(トレーニング) = 0.97
#                 : 1390. 正答率(テスト) = 0.9516
# Generation: 1400. 正答率(トレーニング) = 0.96
#                 : 1400. 正答率(テスト) = 0.9493
# Generation: 1410. 正答率(トレーニング) = 0.97
#                 : 1410. 正答率(テスト) = 0.9492
# Generation: 1420. 正答率(トレーニング) = 0.93
#                 : 1420. 正答率(テスト) = 0.9512
# Generation: 1430. 正答率(トレーニング) = 0.97
#                 : 1430. 正答率(テスト) = 0.9518
# Generation: 1440. 正答率(トレーニング) = 0.97
#                 : 1440. 正答率(テスト) = 0.951
# Generation: 1450. 正答率(トレーニング) = 0.96
#                 : 1450. 正答率(テスト) = 0.9542
# Generation: 1460. 正答率(トレーニング) = 0.96
#                 : 1460. 正答率(テスト) = 0.9511
# Generation: 1470. 正答率(トレーニング) = 0.98
#                 : 1470. 正答率(テスト) = 0.9488
# Generation: 1480. 正答率(トレーニング) = 0.99
#                 : 1480. 正答率(テスト) = 0.953
# Generation: 1490. 正答率(トレーニング) = 1.0
#                 : 1490. 正答率(テスト) = 0.9516
# Generation: 1500. 正答率(トレーニング) = 0.99
#                 : 1500. 正答率(テスト) = 0.9496
# Generation: 1510. 正答率(トレーニング) = 0.99
#                 : 1510. 正答率(テスト) = 0.9466
# Generation: 1520. 正答率(トレーニング) = 0.98
#                 : 1520. 正答率(テスト) = 0.9529
# Generation: 1530. 正答率(トレーニング) = 0.97
#                 : 1530. 正答率(テスト) = 0.9491
# Generation: 1540. 正答率(トレーニング) = 0.96
#                 : 1540. 正答率(テスト) = 0.9486
# Generation: 1550. 正答率(トレーニング) = 0.98
#                 : 1550. 正答率(テスト) = 0.954
# Generation: 1560. 正答率(トレーニング) = 0.96
#                 : 1560. 正答率(テスト) = 0.9497
# Generation: 1570. 正答率(トレーニング) = 0.96
#                 : 1570. 正答率(テスト) = 0.9554
# Generation: 1580. 正答率(トレーニング) = 0.96
#                 : 1580. 正答率(テスト) = 0.9518
# Generation: 1590. 正答率(トレーニング) = 0.98
#                 : 1590. 正答率(テスト) = 0.9532
# Generation: 1600. 正答率(トレーニング) = 0.95
#                 : 1600. 正答率(テスト) = 0.9517
# Generation: 1610. 正答率(トレーニング) = 0.97
#                 : 1610. 正答率(テスト) = 0.9486
# Generation: 1620. 正答率(トレーニング) = 0.99
#                 : 1620. 正答率(テスト) = 0.9483
# Generation: 1630. 正答率(トレーニング) = 0.97
#                 : 1630. 正答率(テスト) = 0.9508
# Generation: 1640. 正答率(トレーニング) = 1.0
#                 : 1640. 正答率(テスト) = 0.9547
# Generation: 1650. 正答率(トレーニング) = 0.98
#                 : 1650. 正答率(テスト) = 0.9535
# Generation: 1660. 正答率(トレーニング) = 0.98
#                 : 1660. 正答率(テスト) = 0.9532
# Generation: 1670. 正答率(トレーニング) = 0.99
#                 : 1670. 正答率(テスト) = 0.9515
# Generation: 1680. 正答率(トレーニング) = 0.98
#                 : 1680. 正答率(テスト) = 0.9505
# Generation: 1690. 正答率(トレーニング) = 0.98
#                 : 1690. 正答率(テスト) = 0.9477
# Generation: 1700. 正答率(トレーニング) = 1.0
#                 : 1700. 正答率(テスト) = 0.9497
# Generation: 1710. 正答率(トレーニング) = 0.97
#                 : 1710. 正答率(テスト) = 0.9476
# Generation: 1720. 正答率(トレーニング) = 0.96
#                 : 1720. 正答率(テスト) = 0.9513
# Generation: 1730. 正答率(トレーニング) = 0.98
#                 : 1730. 正答率(テスト) = 0.954
# Generation: 1740. 正答率(トレーニング) = 0.99
#                 : 1740. 正答率(テスト) = 0.9555
# Generation: 1750. 正答率(トレーニング) = 0.93
#                 : 1750. 正答率(テスト) = 0.9449
# Generation: 1760. 正答率(トレーニング) = 0.99
#                 : 1760. 正答率(テスト) = 0.9555
# Generation: 1770. 正答率(トレーニング) = 0.95
#                 : 1770. 正答率(テスト) = 0.9535
# Generation: 1780. 正答率(トレーニング) = 0.99
#                 : 1780. 正答率(テスト) = 0.9564
# Generation: 1790. 正答率(トレーニング) = 0.97
#                 : 1790. 正答率(テスト) = 0.9522
# Generation: 1800. 正答率(トレーニング) = 0.95
#                 : 1800. 正答率(テスト) = 0.9529
# Generation: 1810. 正答率(トレーニング) = 0.94
#                 : 1810. 正答率(テスト) = 0.9545
# Generation: 1820. 正答率(トレーニング) = 0.98
#                 : 1820. 正答率(テスト) = 0.9549
# Generation: 1830. 正答率(トレーニング) = 0.97
#                 : 1830. 正答率(テスト) = 0.9563
# Generation: 1840. 正答率(トレーニング) = 0.95
#                 : 1840. 正答率(テスト) = 0.955
# Generation: 1850. 正答率(トレーニング) = 0.99
#                 : 1850. 正答率(テスト) = 0.9574
# Generation: 1860. 正答率(トレーニング) = 0.98
#                 : 1860. 正答率(テスト) = 0.9565
# Generation: 1870. 正答率(トレーニング) = 0.98
#                 : 1870. 正答率(テスト) = 0.9564
# Generation: 1880. 正答率(トレーニング) = 0.97
#                 : 1880. 正答率(テスト) = 0.9533
# Generation: 1890. 正答率(トレーニング) = 0.98
#                 : 1890. 正答率(テスト) = 0.9506
# Generation: 1900. 正答率(トレーニング) = 0.99
#                 : 1900. 正答率(テスト) = 0.9577
# Generation: 1910. 正答率(トレーニング) = 0.99
#                 : 1910. 正答率(テスト) = 0.9562
# Generation: 1920. 正答率(トレーニング) = 1.0
#                 : 1920. 正答率(テスト) = 0.9566
# Generation: 1930. 正答率(トレーニング) = 0.99
#                 : 1930. 正答率(テスト) = 0.9508
# Generation: 1940. 正答率(トレーニング) = 0.98
#                 : 1940. 正答率(テスト) = 0.9571
# Generation: 1950. 正答率(トレーニング) = 0.98
#                 : 1950. 正答率(テスト) = 0.9588
# Generation: 1960. 正答率(トレーニング) = 0.98
#                 : 1960. 正答率(テスト) = 0.9569
# Generation: 1970. 正答率(トレーニング) = 0.97
#                 : 1970. 正答率(テスト) = 0.9557
# Generation: 1980. 正答率(トレーニング) = 0.99
#                 : 1980. 正答率(テスト) = 0.9575
# Generation: 1990. 正答率(トレーニング) = 0.97
#                 : 1990. 正答率(テスト) = 0.9589
# Generation: 2000. 正答率(トレーニング) = 0.97
#                 : 2000. 正答率(テスト) = 0.9559

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] hidden_size_listの数字を変更してみよう

# %% [markdown]
# ## [try] sigmoid - He と relu - Xavier についても試してみよう
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
