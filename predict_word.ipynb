# %% [markdown]
# <a href="https://colab.research.google.com/github/ffalo64/rabbit_challenge/blob/main/predict_word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 準備

# %% [markdown]
# ## Google Colab 用の処理
#
# 下記を実行します
# - ドライブのマウント
# - ノートブックファイルと同じフォルダへの移動
#
# Googleドライブのマイドライブ を基準に DNN_code/DNN_code_colab_day3 フォルダを置くことを仮定しています。必要に応じて，パスを変更してください．

# %%
# Google Colab での実行かを調べる
import sys
import os
ENV_COLAB = True  if 'google.colab' in sys.modules else False 

# google drive のマウント
if ENV_COLAB:
  from google.colab import drive 
  drive.mount('/content/drive')
  os.chdir('/content/drive/My Drive/DNN_code/DNN_code_colab_day3/notebook/3_2_tf_languagemodel')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # predict_word

# %%
import tensorflow as tf
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)

tf.config.run_functions_eagerly(False)

# %%
import numpy as np
import re
import glob
import collections
import pickle

class Corpus:
    def __init__(self):
        self.unknown_word_symbol = "<???>" # 出現回数の少ない単語は未知語として定義しておく
        self.unknown_word_threshold = 3 # 未知語と定義する単語の出現回数の閾値
        self.corpus_file = "./corpus/**/*.txt"
        self.corpus_encoding = "utf-8"
        self.dictionary_filename = "./data_for_predict/word_dict.dic"
        self.chunk_size = 5
        self.load_dict()
        words = []
        for filename in glob.glob(self.corpus_file, recursive=True):
            with open(filename, "r", encoding=self.corpus_encoding) as f:
                # word breaking
                text = f.read()
                # 全ての文字を小文字に統一し、改行をスペースに変換
                text = text.lower().replace("\n", " ")
                # 特定の文字以外の文字を空文字に置換する
                text = re.sub(r"[^a-z '\-]", "", text)
                # 複数のスペースはスペース一文字に変換
                text = re.sub(r"[ ]+", " ", text)

                # 前処理： '-' で始まる単語は無視する
                words = [ word for word in text.split() if not word.startswith("-")]

        self.data_n = len(words) - self.chunk_size
        self.data = self.seq_to_matrix(words)

    def prepare_data(self):
        """
        訓練データとテストデータを準備する。
        data_n = ( text データの総単語数 ) - chunk_size
        input: (data_n, chunk_size, vocabulary_size)
        output: (data_n, vocabulary_size)
        """

        # 入力と出力の次元テンソルを準備
        all_input = np.zeros([self.chunk_size, self.vocabulary_size, self.data_n])
        all_output = np.zeros([self.vocabulary_size, self.data_n])

        # 準備したテンソルに、コーパスの one-hot 表現(self.data) のデータを埋めていく
        # i 番目から ( i + chunk_size - 1 ) 番目までの単語が１組の入力となる
        # このときの出力は ( i + chunk_size ) 番目の単語
        for i in range(self.data_n):
            all_output[:, i] = self.data[:, i + self.chunk_size] # (i + chunk_size) 番目の単語の one-hot ベクトル
            for j in range(self.chunk_size):
                all_input[j, :, i] = self.data[:, i + self.chunk_size - j - 1]

        # 後に使うデータ形式に合わせるために転置を取る
        all_input = all_input.transpose([2, 0, 1])
        all_output = all_output.transpose()

        # 訓練データ：テストデータを 4 : 1 に分割する
        training_num = ( self.data_n * 4 ) // 5
        return all_input[:training_num], all_output[:training_num], all_input[training_num:], all_output[training_num:]


    def build_dict(self):
        # コーパス全体を見て、単語の出現回数をカウントする
        counter = collections.Counter()
        for filename in glob.glob(self.corpus_file, recursive=True):
            with open(filename, "r", encoding=self.corpus_encoding) as f:

                # word breaking
                text = f.read()
                # 全ての文字を小文字に統一し、改行をスペースに変換
                text = text.lower().replace("\n", " ")
                # 特定の文字以外の文字を空文字に置換する
                text = re.sub(r"[^a-z '\-]", "", text)
                # 複数のスペースはスペース一文字に変換
                text = re.sub(r"[ ]+", " ", text)

                # 前処理： '-' で始まる単語は無視する
                words = [word for word in text.split() if not word.startswith("-")]

                counter.update(words)

        # 出現頻度の低い単語を一つの記号にまとめる
        word_id = 0
        dictionary = {}
        for word, count in counter.items():
            if count <= self.unknown_word_threshold:
                continue

            dictionary[word] = word_id
            word_id += 1
        dictionary[self.unknown_word_symbol] = word_id

        print("総単語数：", len(dictionary))

        # 辞書を pickle を使って保存しておく
        with open(self.dictionary_filename, "wb") as f:
            pickle.dump(dictionary, f)
            print("Dictionary is saved to", self.dictionary_filename)

        self.dictionary = dictionary
        print(self.dictionary)

    def load_dict(self):
        with open(self.dictionary_filename, "rb") as f:
            self.dictionary = pickle.load(f)
            self.vocabulary_size = len(self.dictionary)
            self.input_layer_size = len(self.dictionary)
            self.output_layer_size = len(self.dictionary)
            print("総単語数: ", self.input_layer_size)

    def get_word_id(self, word):
        # print(word)
        # print(self.dictionary)
        # print(self.unknown_word_symbol)
        # print(self.dictionary[self.unknown_word_symbol])
        # print(self.dictionary.get(word, self.dictionary[self.unknown_word_symbol]))
        return self.dictionary.get(word, self.dictionary[self.unknown_word_symbol])

    # 入力された単語を one-hot ベクトルにする
    def to_one_hot(self, word):
        index = self.get_word_id(word)
        data = np.zeros(self.vocabulary_size)
        data[index] = 1
        return data

    def seq_to_matrix(self, seq):
        # print(seq)
        data = np.array([self.to_one_hot(word) for word in seq]) # (data_n, vocabulary_size)
        return data.transpose() # (vocabulary_size, data_n)

def build_dict():
    cp = Corpus()
    cp.build_dict()

# %%
import time
import datetime

class Language:
    """
    input layer: self.vocabulary_size
    hidden layer: rnn_size = 30
    output layer: self.vocabulary_size
    """

    def __init__(self):
        self.corpus = Corpus()
        self.dictionary = self.corpus.dictionary
        self.vocabulary_size = len(self.dictionary) # 単語数
        self.input_layer_size = self.vocabulary_size # 入力層の数
        self.hidden_layer_size = 30 # 隠れ層の RNN ユニットの数
        self.output_layer_size = self.vocabulary_size # 出力層の数
        self.batch_size = 128 # バッチサイズ
        self.chunk_size = 5 # 展開するシーケンスの数。c_0, c_1, ..., c_(chunk_size - 1) を入力し、c_(chunk_size) 番目の単語の確率が出力される。
        self.learning_rate = 0.001 # 学習率
        self.epochs = 50 # 学習するエポック数
        self.forget_bias = 1.0 # LSTM における忘却ゲートのバイアス
        self.model_filename = "./data_for_predict/predict_model.ckpt"
        self.unknown_word_symbol = self.corpus.unknown_word_symbol

        # RNN 入力前の Embedding のパラメータ　
        self.hidden_w = tf.Variable(tf.random.truncated_normal([self.input_layer_size, self.hidden_layer_size], stddev=0.01))
        self.hidden_b = tf.Variable(tf.ones([self.hidden_layer_size]))

        # RNN 出力後の 全結合層のパラメータ
        self.output_w = tf.Variable(tf.random.truncated_normal([self.hidden_layer_size, self.output_layer_size], stddev=0.01))
        self.output_b = tf.Variable(tf.ones([self.output_layer_size]))

        # RNN 
        #self.rnn = tf.keras.layers.SimpleRNN(self.hidden_layer_size, activation='tanh', return_sequences=True)
        self.rnn = tf.keras.layers.SimpleRNN(self.hidden_layer_size, activation='tanh')
        # SimpleRNN Layer の weight を 強制的に生成させる 
        self.rnn(np.zeros((self.chunk_size, self.batch_size, self.hidden_layer_size),np.float32)) 

        self.trainable_variables = [self.hidden_w, self.hidden_b, self.output_w, self.output_b, *self.rnn.trainable_variables]

        self.optimizer = None

    def load_weights(self, ckpt_path):
        ckpt = tf.train.load_checkpoint(ckpt_path)

        # checkpoint から明示的に変数名を指定して保存
        self.hidden_w=tf.Variable(ckpt.get_tensor("hidden_w/.ATTRIBUTES/VARIABLE_VALUE"))
        self.hidden_b=tf.Variable(ckpt.get_tensor("hidden_b/.ATTRIBUTES/VARIABLE_VALUE"))
        self.output_w=tf.Variable(ckpt.get_tensor("output_w/.ATTRIBUTES/VARIABLE_VALUE"))
        self.output_b=tf.Variable(ckpt.get_tensor("output_b/.ATTRIBUTES/VARIABLE_VALUE"))
        k1 = tf.Variable(ckpt.get_tensor("rnn_kernel/.ATTRIBUTES/VARIABLE_VALUE"))
        k2 = tf.Variable(ckpt.get_tensor("rnn_reccurent_kernel/.ATTRIBUTES/VARIABLE_VALUE"))
        b  = tf.Variable(ckpt.get_tensor("rnn_bias/.ATTRIBUTES/VARIABLE_VALUE"))
        self.rnn.set_weights([k1,k2,b])
        return
    
    def save_weights(self, model_file):
        ckpt_tf2 = tf.train.Checkpoint(hidden_w=self.hidden_w, hidden_b=self.hidden_b, 
                               output_w=self.output_w, output_b=self.output_b, 
                               rnn_kernel=self.rnn.weights[0], rnn_reccurent_kernel=self.rnn.weights[1], rnn_bias=self.rnn.weights[2])
        save_path = ckpt_tf2.save(model_file)
        print(save_path, "was saved")
        return
        
    @tf.function
    def inference(self, input_data, initial_state):
        """
        :param input_data: (batch_size, chunk_size, vocabulary_size) 次元のテンソル
        :param initial_state: (batch_size, hidden_layer_size) 次元の行列
        :return:
        """
        batch_size, chunk_size, vocab_size = input_data.shape
        
        # 現時点での入力データは (batch_size, chunk_size, input_layer_size) という３次元のテンソル
        # chunkc_size * batch_size 分の単語に対して一気に 演算を行うため tf.transpose, tf.reshape を駆使してサイズ調整する

        # shape 調整
        input_data = tf.transpose(a=input_data, perm=[1, 0, 2]) # 転置。(chunk_size, batch_size, vocabulary_size)
        input_data = tf.reshape(input_data, [-1, self.input_layer_size]) # 変形。(chunk_size * batch_size, input_layer_size)
        # 単語(シンボル)の ベクトル化
        input_data = tf.matmul(input_data, self.hidden_w) + self.hidden_b # 重みWとバイアスBを適用。 (chunk_size * batch_size, hidden_layer_size)
        # shape を 元に戻す
        input_data = tf.reshape(input_data, [chunk_size, batch_size, self.hidden_layer_size]) # 変形。(chunk_size,  batch_size, hidden_layer_size)
        input_data = tf.transpose(a=input_data, perm=[1, 0, 2]) # 転置。(batch_size, chunk_size, hidden_layer_size)
            
        # RNN の演算 予測が行えればよいので 最後の単語のみ得る
        output = self.rnn(input_data, initial_state=initial_state)
        
        # 最後に隠れ層から出力層につながる重みとバイアスを処理する
        # 最終的に softmax 関数で処理し、確率として解釈される。
        # softmax 関数はこの関数の外で定義する。
        output = tf.matmul(output, self.output_w) + self.output_b

        # # print weights
        # print(self.hidden_w[0,0]) 
        # print(self.hidden_b[0]) 
        # print(self.output_w[0,0]) 
        # print(self.output_b[0]) 
        # print(self.rnn.weights[0][0,0]) 
        # print(self.rnn.weights[1][0,0]) 
        # print(self.rnn.weights[2][0]) 
                 
        return output

    def training(self):
        # 今回は最適化手法として Adam を選択する。
        # ここの Adam の部分を変えることで、Adagrad, Adadelta などの他の最適化手法を選択することができる
        optimizer = tf.optimizers.Adam(learning_rate=self.learning_rate)
        return optimizer

    @tf.function
    def loss(self, logits, labels):
        cost = tf.reduce_mean(input_tensor=tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf.stop_gradient(labels)))
        return cost

    @tf.function
    def accuracy(self, prediction, labels):
        correct = tf.equal(tf.argmax(input=prediction, axis=1), tf.argmax(input=labels, axis=1))
        accuracy = tf.reduce_mean(input_tensor=tf.cast(correct, tf.float32))
        return accuracy

    @tf.function
    def train_step(self, inputs, labels, initial_state):
        with tf.GradientTape() as tape:
            prediction = self.inference(inputs, initial_state)
            loss = self.loss(prediction, labels)

        gradients = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        acc  = self.accuracy(prediction, labels)
        return loss, acc

    def train(self, model_file):
        """
        :param save_ckpt: 学習した重み係数を保存する checkpoint の名前
        :return:
        """
        # 訓練・テストデータの用意
        trX, trY, teX, teY = self.corpus.prepare_data()
        training_num = trX.shape[0]

        # ここから実際に学習を走らせる
        # エポックを回す
        log_train_acc = []
        log_train_loss = []
        # log_val_acc = []
        # log_val_loss = [] 
        self.optimizer = self.training()
        for epoch in range(self.epochs):
            step = 0
            epoch_loss = 0
            epoch_acc = 0

            # 訓練データをバッチサイズごとに分けて学習させる (= optimizer を走らせる)
            # エポックごとの損失関数の合計値や（訓練データに対する）精度も計算しておく
            while (step + 1) * self.batch_size < training_num:
                start_idx = step * self.batch_size
                end_idx = (step + 1) * self.batch_size

                batch_xs = tf.Variable(trX[start_idx:end_idx, :, :].astype(np.float32))
                batch_ys = tf.Variable(trY[start_idx:end_idx, :].astype(np.float32))
                initial_state = tf.Variable(np.zeros([self.batch_size, self.hidden_layer_size],dtype=np.float32))
                c, a = self.train_step(batch_xs, batch_ys, initial_state)
                # print("Epoch:", epoch, ", step:", step, "-- loss:", c, " -- accuracy:", a)
                epoch_loss += c
                epoch_acc += a
                step += 1
            # コンソールに損失関数の値や精度を出力しておく
            print("Epoch", epoch, "completed ouf of", self.epochs, "-- loss:", epoch_loss/step, " -- accuracy:",
                    epoch_acc / step)
            log_train_acc.append( (epoch_acc / step).numpy())
            log_train_loss.append((epoch_loss/step ).numpy() )
            
        # 最後にテストデータでの精度を計算して表示する
        inputs = tf.Variable(teX.astype(np.float32))
        initial_state = tf.Variable(np.zeros([teX.shape[0], self.hidden_layer_size],dtype=np.float32))
        labels = tf.Variable(teY.astype(np.float32))
        prediction = self.inference(inputs,initial_state)
        a = self.accuracy(prediction, labels)
        c = self.loss(prediction ,labels)
        # log_val_acc.append( a.numpy() )
        # log_val_loss.append( c.numpy() )

        history = {"train_acc": log_train_acc, "train_loss": log_train_loss
        #, "val_acc":log_val_acc, "val_loss":log_val_loss
        }
        print("Accuracy on test:", a.numpy())
        
        # 学習したモデルも保存しておく
        self.save_weights(model_file)
        return history
    
    def predict(self, seq):
        """
        文章を入力したときに次に来る単語を予測する
        :param seq: 予測したい単語の直前の文字列。chunk_size 以上の単語数が必要。
        :return: 
        """
        @tf.function
        def get_predictions(input_data, initial_state):
            return tf.nn.softmax(self.inference(input_data, initial_state))

        @tf.function
        def get_predicted_labels(predictions):
            return tf.argmax(predictions, axis=1)    

        # ----------- 入力データの作成
        # seq を one-hot 表現に変換する。
        words = [word for word in seq.split() if not word.startswith("-")]
        x = np.zeros([1, self.chunk_size, self.input_layer_size], dtype=np.float32)
        for i in range(self.chunk_size):
            word = seq[len(words) - self.chunk_size + i]
            index = self.dictionary.get(word, self.dictionary[self.unknown_word_symbol])
            x[0][i][index] = 1
        x = tf.Variable(x)
        initial_state = tf.Variable(np.zeros((1,self.hidden_layer_size), dtype=np.float32))
        
        # ----------- ロードしたモデルを使って各単語の出力確率を計算 (tensorflow による計算)
        u = get_predictions(x, initial_state)
         
        # ----------  結果表示
        keys = list(self.dictionary.keys())    

        # 各単語の確率の表示
        display_num = self.vocabulary_size # 10        
        print("各単語の出現確率 (降順)")
        sorted_index = np.argsort(-u[0])
        for i in sorted_index[:display_num]:
            c = self.unknown_word_symbol if i == (self.vocabulary_size - 1) else keys[i]
            print(c, ":", u[0][i].numpy())

        # 最も確率が大きいものを予測結果とする
        v = get_predicted_labels(u)
        print()
        print("Prediction:", seq + " " + ("<???>" if v[0] == (self.vocabulary_size - 1) else keys[v[0]]))


        return

# %% [markdown]
# 構築済みの辞書と、学習済みのパラメータを用いて予測を行う

# %%
ln = Language()

# 学習済みのパラメータをロード
ln.load_weights("./data_for_predict/predict_model")

# 保存したモデルを使って単語の予測をする
ln.predict("some of them looks like")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# matrix : 1.4417937e-14
# heston's : 1.4417661e-14
# pif : 1.4416892e-14
# hm : 1.4416782e-14
# outer : 1.4416728e-14
# mortgages : 1.4416672e-14
# newest : 1.4416562e-14
# evolution : 1.4416508e-14
# scores : 1.4416123e-14
# occupation : 1.4416123e-14
# personally : 1.4416067e-14
# paste : 1.4415766e-14
# units : 1.4415296e-14
# civilian : 1.4414417e-14
# sarah : 1.4414307e-14
# imagined : 1.441428e-14
# appearance : 1.4414033e-14
# sign : 1.4413868e-14
# vary : 1.4413565e-14
# transformation : 1.4413538e-14
# stlp : 1.4413263e-14
# quoted : 1.4412547e-14
# slower : 1.4412493e-14
# accident : 1.4412493e-14
# jury : 1.4412438e-14
# distributor : 1.4412382e-14
# murder : 1.4412328e-14
# beth : 1.4412272e-14
# principal : 1.4412218e-14
# amazing : 1.4412054e-14
# inevitably : 1.4411944e-14
# kid : 1.4410844e-14
# father : 1.441035e-14
# ghana : 1.441021e-14
# problematic : 1.4409963e-14
# nod : 1.4409635e-14
# sword : 1.4409469e-14
# pthe : 1.4409414e-14
# incompetent : 1.4408839e-14
# mine : 1.4408618e-14
# unhappy : 1.4408315e-14
# frown : 1.4408234e-14
# sing : 1.4407847e-14
# breaking : 1.44076e-14
# enclosing : 1.440749e-14
# thrust : 1.4407353e-14
# disclosure : 1.4406885e-14
# velvet : 1.4406831e-14
# resolutions : 1.4406199e-14
# sums : 1.4406116e-14
# assist : 1.4406089e-14
# team : 1.4405677e-14
# adrienne : 1.4405239e-14
# pressing : 1.4405239e-14
# tried : 1.4405128e-14
# done : 1.4405128e-14
# lawyer : 1.4405073e-14
# strategies : 1.4404962e-14
# fetal : 1.4404798e-14
# plain : 1.4404524e-14
# conduct : 1.4404303e-14
# in-nest : 1.440414e-14
# collectors : 1.4403973e-14
# full-time : 1.4403865e-14
# romantic : 1.4403836e-14
# drafted : 1.4403424e-14
# shouts : 1.4403177e-14
# devoted : 1.440304e-14
# fired : 1.4402682e-14
# risky : 1.4402518e-14
# morning : 1.4402518e-14
# interfere : 1.4402408e-14
# definitions : 1.4402188e-14
# bold : 1.440194e-14
# boston : 1.4401337e-14
# stimulates : 1.4401254e-14
# harsh : 1.4401036e-14
# ago : 1.4400926e-14
# tx : 1.4400897e-14
# beaches : 1.4400732e-14
# suspended : 1.4400512e-14
# educate : 1.4400458e-14
# increasing : 1.440021e-14
# name : 1.4399909e-14
# inclined : 1.4399523e-14
# galilee : 1.4399248e-14
# associate : 1.4399248e-14
# gangs : 1.4399084e-14
# purely : 1.4399084e-14
# vault : 1.439903e-14
# ava : 1.4398974e-14
# rooms : 1.439848e-14
# clusters : 1.439793e-14
# allocation : 1.4397492e-14
# debts : 1.4396997e-14
# walking : 1.4396997e-14
# wallet : 1.4396997e-14
# guggenheim : 1.4396723e-14
# harmonic : 1.4396394e-14
# hallway : 1.4396064e-14
# transform : 1.4396036e-14
# vacation : 1.439601e-14
# specifically : 1.4395926e-14
# primerica : 1.4395845e-14
# outdated : 1.4395762e-14
# decisions : 1.439557e-14
# hybridization : 1.439546e-14
# youve : 1.4394691e-14
# dallas : 1.4394691e-14
# hong : 1.4393538e-14
# info : 1.4393317e-14
# feelings : 1.4393072e-14
# subject : 1.4393072e-14
# wisest : 1.4392935e-14
# witnessed : 1.4392824e-14
# darwin's : 1.4392658e-14
# columbia : 1.4392658e-14
# outlying : 1.4392658e-14
# intention : 1.4392494e-14
# urgent : 1.4392384e-14
# collapse : 1.439233e-14
# putting : 1.4392274e-14
# french : 1.4392274e-14
# noted : 1.4392166e-14
# rows : 1.4392082e-14
# villages : 1.4392082e-14
# they're : 1.4391891e-14
# alluvial : 1.4391891e-14
# wanted : 1.4391862e-14
# sustained : 1.4391507e-14
# please : 1.439137e-14
# hereafter : 1.4391176e-14
# drags : 1.4391068e-14
# 'em : 1.4390848e-14
# posts : 1.4390353e-14
# urgently : 1.4390353e-14
# weick : 1.4390243e-14
# compelling : 1.4390216e-14
# cleared : 1.4389858e-14
# personal : 1.438975e-14
# hated : 1.4389584e-14
# translate : 1.4389475e-14
# technologies : 1.438942e-14
# judy : 1.4389255e-14
# preferences : 1.4388816e-14
# senttue : 1.4388322e-14
# jackson : 1.438813e-14
# difficult : 1.4387993e-14
# gland : 1.4387719e-14
# heidi : 1.4387719e-14
# control : 1.4387636e-14
# sauce : 1.438717e-14
# pheromones : 1.438695e-14
# should : 1.4386812e-14
# delayed : 1.4386594e-14
# larger : 1.4386565e-14
# intentionality : 1.4386346e-14
# leans : 1.438629e-14
# diaper : 1.4385962e-14
# rain : 1.4385743e-14
# hiking : 1.438566e-14
# answering : 1.4385523e-14
# powell : 1.4385496e-14
# logo : 1.4385386e-14
# emotional : 1.4385386e-14
# kean : 1.4385194e-14
# admire : 1.438481e-14
# opera : 1.4384783e-14
# sentwed : 1.4384756e-14
# distribute : 1.438459e-14
# manhattan : 1.4384261e-14
# revelation : 1.4384234e-14
# delete : 1.438407e-14
# focused : 1.4383438e-14
# christy : 1.4383163e-14
# butler : 1.4383109e-14
# paula : 1.4382999e-14
# hide : 1.4382614e-14
# compare : 1.4382506e-14
# excitement : 1.4381984e-14
# duel : 1.4381984e-14
# d- : 1.4381847e-14
# lf : 1.4381793e-14
# angels : 1.4381462e-14
# merchants : 1.438064e-14
# you : 1.4380614e-14
# cannons : 1.438042e-14
# goldfish : 1.438031e-14
# amen : 1.4380256e-14
# novel : 1.4380202e-14
# listing : 1.43799e-14
# preparation : 1.4379736e-14
# attempted : 1.437968e-14
# expanded : 1.4379543e-14
# descending : 1.4379324e-14
# vince : 1.4378665e-14
# expects : 1.4378447e-14
# abx : 1.4377734e-14
# thesis : 1.437757e-14
# pr : 1.437702e-14
# films : 1.4376582e-14
# radio : 1.4376197e-14
# enforce : 1.4376197e-14
# freedom : 1.4376143e-14
# cliff : 1.4376087e-14
# obviously : 1.4376087e-14
# dumb : 1.4376087e-14
# catching : 1.4375896e-14
# forth : 1.4375374e-14
# architect : 1.4374881e-14
# favored : 1.4374552e-14
# ongoing : 1.437447e-14
# pretty : 1.4374332e-14
# government's : 1.4374197e-14
# accepts : 1.4374168e-14
# male : 1.4373839e-14
# flung : 1.4373675e-14
# unemployed : 1.4373483e-14
# persistent : 1.4373292e-14
# despite : 1.4373072e-14
# enemy : 1.4373072e-14
# amended : 1.4372635e-14
# fuck : 1.4372579e-14
# disappointment : 1.4372387e-14
# limits : 1.4372086e-14
# frequently : 1.4371976e-14
# blog : 1.4371866e-14
# oral : 1.4371042e-14
# recovering : 1.4371015e-14
# employees : 1.4370824e-14
# testing : 1.437066e-14
# blows : 1.4370495e-14
# dart : 1.4369892e-14
# farther : 1.4369563e-14
# dearest : 1.4369318e-14
# resistance : 1.436896e-14
# instrument : 1.4368523e-14
# wyvern : 1.4368467e-14
# kerry : 1.4368413e-14
# hesitate : 1.4368359e-14
# rabinowitz : 1.4367864e-14
# minimalism : 1.4367508e-14
# convention : 1.436748e-14
# we'll : 1.4367371e-14
# suits : 1.4366876e-14
# recipients : 1.4366604e-14
# contention : 1.4366055e-14
# pfinally : 1.4365508e-14
# islam : 1.4365508e-14
# purchased : 1.4365398e-14
# wins : 1.4365015e-14
# ruled : 1.4364988e-14
# slaps : 1.4364905e-14
# kindly : 1.436485e-14
# train : 1.4364191e-14
# alaska : 1.4363863e-14
# hundreds : 1.4363781e-14
# unpublished : 1.4363316e-14
# letting : 1.4363261e-14
# military : 1.4362768e-14
# register : 1.436255e-14
# entering : 1.4362521e-14
# middendetect : 1.436244e-14
# produced : 1.4362165e-14
# devastation : 1.4362057e-14
# buses : 1.4361616e-14
# objected : 1.4361206e-14
# isay : 1.4360959e-14
# encounter : 1.4360439e-14
# seltzer : 1.4360083e-14
# attacks : 1.4359838e-14
# doesn't : 1.4359728e-14
# sun : 1.4359426e-14
# gougne : 1.4359097e-14
# we'd : 1.4358713e-14
# boost : 1.4358577e-14
# audio : 1.4358577e-14
# rose : 1.435844e-14
# wounded : 1.435833e-14
# church : 1.4358057e-14
# ascending : 1.4357947e-14
# interface : 1.435792e-14
# identities : 1.4357674e-14
# pilgrims : 1.4357537e-14
# endangered : 1.4357483e-14
# year's : 1.4357346e-14
# messages : 1.4357044e-14
# largest : 1.4356797e-14
# dishes : 1.4356741e-14
# love : 1.435625e-14
# wanna : 1.4355155e-14
# academy : 1.43551e-14
# bronze : 1.435466e-14
# tail : 1.4354496e-14
# laughed : 1.4354442e-14
# maintenance : 1.4353949e-14
# labor : 1.4353785e-14
# wake : 1.435373e-14
# souls : 1.435362e-14
# ethics : 1.4353265e-14
# moments : 1.4353238e-14
# cameras : 1.4353183e-14
# everywhere : 1.4353129e-14
# residential : 1.435217e-14
# declined : 1.4351732e-14
# paige : 1.4350993e-14
# whole-tone : 1.4350993e-14
# zealand : 1.4350171e-14
# links : 1.434998e-14
# senior : 1.4349926e-14
# standing : 1.4349788e-14
# nep : 1.4349734e-14
# eyebrow : 1.4349351e-14
# furthermore : 1.4348638e-14
# written : 1.4348611e-14
# come : 1.434842e-14
# masters : 1.4348365e-14
# chairs : 1.4348284e-14
# amp : 1.4348255e-14
# ca : 1.4348255e-14
# grew : 1.4347627e-14
# unilateral : 1.4347544e-14
# political : 1.4347544e-14
# incubated : 1.4347024e-14
# robot : 1.4346997e-14
# lifted : 1.4346668e-14
# description : 1.4346587e-14
# skin : 1.4346587e-14
# portions : 1.4346341e-14
# rape : 1.4345902e-14
# eventually : 1.4345765e-14
# referendum : 1.4345628e-14
# afghanistan : 1.4345082e-14
# interconnection : 1.4344972e-14
# intact : 1.4344808e-14
# rail : 1.4344672e-14
# dropping : 1.4344207e-14
# hepatitis : 1.434415e-14
# phase : 1.4343576e-14
# himself : 1.4343166e-14
# conclusion : 1.4343166e-14
# raggett : 1.4343112e-14
# fourths : 1.4342374e-14
# hydrogen : 1.4342126e-14
# pillow : 1.43418e-14
# general : 1.4341086e-14
# delay : 1.4340705e-14
# fourteen : 1.4339993e-14
# storm : 1.4339173e-14
# trillion : 1.4339063e-14
# mickey : 1.4338406e-14
# fuller : 1.4338298e-14
# research : 1.4338215e-14
# right : 1.4337723e-14
# forex : 1.4337478e-14
# attainment : 1.4337259e-14
# scam : 1.4337149e-14
# distant : 1.4336985e-14
# aphrodite : 1.4336493e-14
# whats : 1.4336329e-14
# wants : 1.4336e-14
# gilbert : 1.4335973e-14
# tentacles : 1.4335892e-14
# press : 1.4335782e-14
# commission : 1.4335672e-14
# lexaburn : 1.4335672e-14
# heavens : 1.433559e-14
# roughly : 1.4335372e-14
# replacement : 1.4334962e-14
# crewmembers : 1.4334908e-14
# face-to-face : 1.4334743e-14
# elbow : 1.4333705e-14
# dark : 1.4333705e-14
# embedded : 1.4333486e-14
# sanctuaries : 1.433332e-14
# illegally : 1.4333048e-14
# inch : 1.4332993e-14
# millennium : 1.4332446e-14
# proposing : 1.4332392e-14
# social : 1.4331735e-14
# peanuts : 1.433138e-14
# rising : 1.4330232e-14
# blinked : 1.433015e-14
# ripple : 1.4330014e-14
# reaches : 1.432963e-14
# floating : 1.4329494e-14
# comfort : 1.4329248e-14
# excuse : 1.4328948e-14
# cities : 1.4328894e-14
# west : 1.4328784e-14
# judges : 1.432873e-14
# crenshaw : 1.432862e-14
# noticed : 1.432851e-14
# stronger : 1.4328401e-14
# embryonic : 1.4328237e-14
# terrorists : 1.4328128e-14
# twelve : 1.4327882e-14
# important : 1.432747e-14
# users : 1.4327281e-14
# licensing : 1.4326653e-14
# chemicals : 1.4326653e-14
# planning : 1.4326378e-14
# recognizable : 1.4326105e-14
# uncertain : 1.4325751e-14
# dedicated : 1.4325614e-14
# diego : 1.432545e-14
# staying : 1.432534e-14
# policy : 1.4324467e-14
# bags : 1.4324303e-14
# adding : 1.4324303e-14
# hooves : 1.432422e-14
# idaaworg : 1.4324193e-14
# ask : 1.4324193e-14
# antie : 1.4324028e-14
# potentially : 1.4323947e-14
# friend : 1.4323702e-14
# programming : 1.4323292e-14
# nj : 1.4323154e-14
# impostors : 1.43231e-14
# lightly : 1.4322882e-14
# driven : 1.432239e-14
# colony : 1.4322336e-14
# calibre : 1.4322172e-14
# gillen : 1.432168e-14
# delivered : 1.4321625e-14
# faces : 1.4321543e-14
# screening : 1.4321242e-14
# computers : 1.4321133e-14
# owns : 1.4320723e-14
# vessel : 1.432037e-14
# bridges : 1.432026e-14
# racing : 1.432026e-14
# faster : 1.4319822e-14
# charsets : 1.431966e-14
# reminded : 1.431933e-14
# pulling : 1.4319167e-14
# skydiving : 1.4319002e-14
# professional : 1.4318675e-14
# theyd : 1.4318675e-14
# weekends : 1.4318182e-14
# timetable : 1.4317855e-14
# washed : 1.4317638e-14
# liver : 1.4317638e-14
# core : 1.431742e-14
# samuel : 1.4317254e-14
# substitution : 1.4317118e-14
# terms : 1.4317091e-14
# dominant : 1.4316573e-14
# avenida : 1.4316519e-14
# watching : 1.4316381e-14
# command : 1.4316326e-14
# laugh : 1.4315836e-14
# middle : 1.431578e-14
# crucifixion : 1.4315534e-14
# start : 1.4315124e-14
# donor : 1.431507e-14
# commented : 1.4314743e-14
# raman : 1.4313815e-14
# exclusive : 1.4313596e-14
# stops : 1.431275e-14
# pews : 1.431275e-14
# carriage : 1.4312395e-14
# ship's : 1.4312287e-14
# ever : 1.4311494e-14
# bruce : 1.4311494e-14
# meaning : 1.4311413e-14
# fill : 1.4311304e-14
# directs : 1.4310866e-14
# webster's : 1.4310512e-14
# systems : 1.4309993e-14
# give : 1.4309775e-14
# brass : 1.4309666e-14
# day : 1.4309556e-14
# prevented : 1.4308983e-14
# ale : 1.4308164e-14
# provisions : 1.4308028e-14
# politics : 1.430792e-14
# essential : 1.4307645e-14
# rivers : 1.4307645e-14
# anymore : 1.4307564e-14
# gods : 1.430751e-14
# jealous : 1.4307483e-14
# revive : 1.430721e-14
# stations : 1.43071e-14
# plane : 1.4306991e-14
# benjaminrogersenroncom : 1.4306827e-14
# vertical : 1.4306717e-14
# czero : 1.4306717e-14
# pig : 1.4306663e-14
# solutions : 1.4306554e-14
# trimethylsilyl : 1.4306254e-14
# meat : 1.4306119e-14
# territorial : 1.4305926e-14
# settlement : 1.4305844e-14
# water : 1.4305409e-14
# grief : 1.4304862e-14
# painting : 1.4304753e-14
# kitten : 1.4304537e-14
# kissing : 1.4304127e-14
# reboot : 1.430369e-14
# oriented : 1.4303335e-14
# valley-floor : 1.4303225e-14
# exposition : 1.4303171e-14
# south : 1.4303117e-14
# mrs : 1.4302761e-14
# stare : 1.4302734e-14
# davy : 1.430268e-14
# tilt : 1.4302626e-14
# western : 1.4302434e-14
# penalty : 1.4301862e-14
# alone : 1.4301807e-14
# intends : 1.4301043e-14
# ss : 1.4301043e-14
# australian : 1.430077e-14
# carrre : 1.430028e-14
# chaos : 1.4300252e-14
# insist : 1.4300171e-14
# dragging : 1.4299788e-14
# wing : 1.4299624e-14
# destroyed : 1.429957e-14
# openly : 1.4299461e-14
# appropriately : 1.4299353e-14
# shaking : 1.4298861e-14
# birds : 1.4298206e-14
# getting : 1.4297825e-14
# conversation : 1.429777e-14
# yelling : 1.4297635e-14
# royal : 1.4296952e-14
# supply : 1.429676e-14
# electric : 1.4296434e-14
# spoke : 1.4296353e-14
# mason : 1.4296353e-14
# edelman : 1.4296053e-14
# factory : 1.4295807e-14
# johns : 1.429578e-14
# attended : 1.4295399e-14
# requirement : 1.4294962e-14
# reluctantly : 1.4294118e-14
# merit : 1.4294062e-14
# beneath : 1.4293654e-14
# mothers : 1.429319e-14
# desperate : 1.4292727e-14
# gate : 1.4292617e-14
# become : 1.4292536e-14
# pointing : 1.429248e-14
# crown : 1.4292426e-14
# helicopter : 1.4291582e-14
# noble : 1.4291418e-14
# latter : 1.4291172e-14
# ralston : 1.4290764e-14
# pathway : 1.4290518e-14
# cars : 1.4290518e-14
# vaccine : 1.4290083e-14
# solar : 1.4289727e-14
# capabilities : 1.4289592e-14
# collapsing : 1.4289292e-14
# cpl : 1.4288556e-14
# investigator : 1.4288174e-14
# cargo : 1.4287684e-14
# academic : 1.4287303e-14
# transport : 1.4287193e-14
# arafat : 1.4286976e-14
# friendship : 1.4286703e-14
# triple : 1.4286676e-14
# shall : 1.4286595e-14
# dwrs : 1.428594e-14
# wrote : 1.4285885e-14
# already : 1.428583e-14
# desired : 1.4285722e-14
# giggled : 1.4285666e-14
# athlete : 1.4285368e-14
# ms : 1.4285287e-14
# wishes : 1.4285204e-14
# nation's : 1.4285012e-14
# wish : 1.428485e-14
# crashes : 1.4284469e-14
# joke : 1.4284414e-14
# countryside : 1.4284277e-14
# terminal : 1.4283869e-14
# starke : 1.428316e-14
# pworking : 1.4282942e-14
# ye : 1.4282588e-14
# moore : 1.4282561e-14
# y- : 1.4282507e-14
# rambling : 1.4282153e-14
# failure : 1.4281989e-14
# explains : 1.4281934e-14
# sponsors : 1.4281199e-14
# backwards : 1.4281064e-14
# indices : 1.4280872e-14
# unprecedented : 1.4280328e-14
# ch : 1.4280137e-14
# mix : 1.4280001e-14
# rank : 1.4279947e-14
# pearl : 1.4279837e-14
# notice : 1.4279783e-14
# informative : 1.4279647e-14
# centre : 1.4279537e-14
# defender : 1.4279456e-14
# formamide : 1.4278748e-14
# sustain : 1.4278531e-14
# laborers : 1.4278094e-14
# motivation : 1.4277823e-14
# t-shirts : 1.4277713e-14
# accents : 1.4277659e-14
# pwhat : 1.4277113e-14
# habits : 1.4276407e-14
# vibrissae : 1.4276188e-14
# thats : 1.4276025e-14
# scan : 1.427597e-14
# grape : 1.4275807e-14
# sbx : 1.427559e-14
# sarah's : 1.4275316e-14
# dose : 1.4275017e-14
# hasn't : 1.427499e-14
# upper : 1.4274772e-14
# bursar : 1.42745e-14
# broken : 1.427442e-14
# daytime : 1.4274201e-14
# enzymes : 1.4274172e-14
# seeing : 1.4274064e-14
# researchers : 1.4274064e-14
# consume : 1.4273901e-14
# trip : 1.427382e-14
# controversy : 1.4273683e-14
# share : 1.4273574e-14
# tweet : 1.4273357e-14
# enron : 1.427333e-14
# hurts : 1.4273195e-14
# requiring : 1.427265e-14
# bliptv : 1.4272322e-14
# sees : 1.4272322e-14
# uh : 1.4272214e-14
# pace : 1.4271124e-14
# minister : 1.4271016e-14
# venturi : 1.4270743e-14
# happier : 1.4270472e-14
# summer : 1.4270416e-14
# positively : 1.4270362e-14
# poems : 1.4270225e-14
# areas : 1.4269873e-14
# independent : 1.4269873e-14
# patients : 1.42696e-14
# hair : 1.426922e-14
# near : 1.4269164e-14
# basses : 1.4269164e-14
# insisted : 1.426884e-14
# production : 1.4268675e-14
# mention : 1.426862e-14
# refund : 1.426851e-14
# determined : 1.4268402e-14
# equus : 1.4268131e-14
# sigh : 1.4267913e-14
# penn : 1.4267804e-14
# keith : 1.4267423e-14
# suffer : 1.4267315e-14
# backing : 1.4267042e-14
# amino : 1.4266877e-14
# recognized : 1.4266823e-14
# pouch : 1.4266634e-14
# inadequate : 1.4266606e-14
# regions : 1.4266307e-14
# captain's : 1.4266252e-14
# glances : 1.4266225e-14
# trick : 1.4266144e-14
# semester : 1.4266117e-14
# deliberate : 1.4265844e-14
# ninja : 1.4264975e-14
# billion : 1.4264511e-14
# sponsor : 1.4264211e-14
# dust : 1.4263859e-14
# eve : 1.4263723e-14
# court : 1.4263505e-14
# crime : 1.4263477e-14
# statutory : 1.4262907e-14
# owners : 1.4262907e-14
# functioning : 1.4262798e-14
# wiped : 1.4262363e-14
# circles : 1.4262063e-14
# conducting : 1.4261982e-14
# carved : 1.42616e-14
# besides : 1.4261384e-14
# appalachian : 1.426084e-14
# lawsuit : 1.426084e-14
# freeze : 1.4260459e-14
# ellen : 1.4260459e-14
# art : 1.4260377e-14
# quiet : 1.4260377e-14
# o'donnell's : 1.4260296e-14
# negative : 1.4260132e-14
# government : 1.4259967e-14
# driving : 1.4259913e-14
# filter : 1.425967e-14
# inappropriate : 1.4259642e-14
# jeffords : 1.4259588e-14
# seafood : 1.4259261e-14
# although : 1.4259153e-14
# backs : 1.4259098e-14
# committee : 1.4258771e-14
# brace : 1.4258065e-14
# receivedmon : 1.4258038e-14
# startled : 1.4257765e-14
# policies : 1.4257411e-14
# trillions : 1.4257086e-14
# wont : 1.4256977e-14
# falls : 1.4256813e-14
# embassy : 1.4256432e-14
# popular : 1.4256025e-14
# alike : 1.4255346e-14
# forecast : 1.4254748e-14
# texas : 1.4254557e-14
# harmony : 1.4254204e-14
# leading : 1.4254096e-14
# viral : 1.4254096e-14
# toronto : 1.4253931e-14
# man's : 1.4253931e-14
# instead : 1.4253415e-14
# scare : 1.4253333e-14
# hockey : 1.425328e-14
# breyer : 1.425328e-14
# doubt : 1.4253034e-14
# screamed : 1.4252952e-14
# sometimes : 1.4252952e-14
# implicit : 1.42523e-14
# partnerships : 1.42523e-14
# changed : 1.42523e-14
# iii : 1.4251704e-14
# ottoman : 1.4251431e-14
# questioned : 1.4251158e-14
# call : 1.425056e-14
# leaves : 1.4250479e-14
# newer : 1.4250479e-14
# beside : 1.4250125e-14
# combat : 1.4249856e-14
# rent : 1.4249691e-14
# game : 1.4249529e-14
# better : 1.4249529e-14
# ozone : 1.4248712e-14
# astonished : 1.4248685e-14
# joy : 1.4248468e-14
# threaten : 1.4248168e-14
# must've : 1.4247762e-14
# bit : 1.4247735e-14
# conducted : 1.4247028e-14
# aid : 1.424692e-14
# cost-effective : 1.4246864e-14
# repeat : 1.4246837e-14
# dialogue : 1.4246539e-14
# hemisphere : 1.4246322e-14
# compromises : 1.4246105e-14
# wow : 1.4245996e-14
# passing : 1.4245778e-14
# class : 1.4245451e-14
# symmetry : 1.4245126e-14
# billing : 1.4244855e-14
# citizen : 1.4244692e-14
# street : 1.4244473e-14
# colleagues : 1.424431e-14
# homosexuality : 1.4243769e-14
# lmao : 1.4243604e-14
# cover : 1.424355e-14
# danger : 1.424268e-14
# ibm : 1.4242598e-14
# producer : 1.4242246e-14
# constitutional : 1.4242246e-14
# terror : 1.4242246e-14
# frantic : 1.4242083e-14
# exact : 1.424154e-14
# fortunately : 1.424116e-14
# computerp : 1.424029e-14
# txb : 1.4240128e-14
# chances : 1.4240072e-14
# mar : 1.4240018e-14
# ski : 1.4239801e-14
# lan : 1.4239693e-14
# tries : 1.4239422e-14
# cites : 1.4239203e-14
# says : 1.423877e-14
# overall : 1.4238715e-14
# ruin : 1.4238498e-14
# prayed : 1.4238363e-14
# tributary : 1.4238336e-14
# giuliani : 1.4238253e-14
# incident : 1.42379e-14
# science : 1.4237873e-14
# gathering : 1.4237738e-14
# marie : 1.4237521e-14
# built : 1.4237384e-14
# tablets : 1.4237248e-14
# he : 1.4237167e-14
# pork : 1.4236815e-14
# receptors : 1.423676e-14
# newspapers : 1.4236433e-14
# comprehensive : 1.4236433e-14
# breathe : 1.4236352e-14
# preferred : 1.4236352e-14
# banking : 1.4236054e-14
# dependent : 1.4236e-14
# byrd : 1.4235946e-14
# mysterious : 1.4235619e-14
# smarter : 1.4235483e-14
# adequately : 1.4235402e-14
# concerts : 1.423513e-14
# shack : 1.4235076e-14
# prominently : 1.4234914e-14
# stamps : 1.4234643e-14
# extend : 1.4234561e-14
# commercial : 1.4234316e-14
# served : 1.4234153e-14
# glucose : 1.423372e-14
# sailor : 1.4233338e-14
# district : 1.4233338e-14
# uh-huh : 1.4233284e-14
# asymmetrical : 1.423323e-14
# senators : 1.4233176e-14
# summary : 1.4232986e-14
# whitney : 1.4232905e-14
# prospective : 1.4232905e-14
# ban : 1.4232796e-14
# puzzled : 1.4231981e-14
# dreamer : 1.4231927e-14
# images : 1.4231873e-14
# ag : 1.4231873e-14
# lanes : 1.4231548e-14
# languages : 1.4231114e-14
# granted : 1.423095e-14
# initiative : 1.4230462e-14
# fixed : 1.4229186e-14
# crop : 1.422894e-14
# ii : 1.4228832e-14
# mr : 1.4228317e-14
# gorgeous : 1.4227477e-14
# boyle : 1.422745e-14
# customized : 1.4227423e-14
# appreciation : 1.4227313e-14
# vi : 1.4227258e-14
# penjoying : 1.422631e-14
# accessed : 1.422517e-14
# nestexit : 1.4225061e-14
# readily : 1.4224709e-14
# vietnam : 1.4224655e-14
# proved : 1.42246e-14
# fairy : 1.4224573e-14
# freddie : 1.4223948e-14
# standard-based : 1.4223787e-14
# prof : 1.4223569e-14
# daysp : 1.4223487e-14
# gow : 1.422346e-14
# incredulously : 1.422308e-14
# longboat : 1.4222756e-14
# slips : 1.4222756e-14
# treat : 1.422026e-14
# citys : 1.4219935e-14
# goddess : 1.421988e-14
# techniques : 1.4219635e-14
# qaeda's : 1.4219527e-14
# interesting : 1.4219012e-14
# package : 1.4218334e-14
# strode : 1.421763e-14
# corresponding : 1.4217384e-14
# fifty : 1.421733e-14
# sponsorship : 1.4217302e-14
# completing : 1.4217277e-14
# pink : 1.4216789e-14
# sentmon : 1.4216789e-14
# misguided : 1.4216245e-14
# boring : 1.4216245e-14
# warnings : 1.4216083e-14
# assert : 1.4216028e-14
# phaving : 1.4216003e-14
# rails : 1.4215866e-14
# developers : 1.4215784e-14
# warmth : 1.421557e-14
# hanging : 1.4215405e-14
# vivid : 1.4215053e-14
# attempts : 1.4214836e-14
# imposing : 1.4214836e-14
# source : 1.4214673e-14
# elbows : 1.4214348e-14
# behind : 1.421386e-14
# rick : 1.4213806e-14
# loading : 1.4213779e-14
# young : 1.4213562e-14
# forms : 1.421348e-14
# breath : 1.4213318e-14
# binding : 1.4212884e-14
# it's : 1.4212613e-14
# fiscal : 1.4211854e-14
# wiser : 1.421131e-14
# jacket : 1.4211204e-14
# beow : 1.4210878e-14
# certificate : 1.4210878e-14
# concludes : 1.4210824e-14
# ark : 1.42101195e-14
# van : 1.4210065e-14
# nickel : 1.4209902e-14
# particle : 1.4209251e-14
# immense : 1.4208818e-14
# russia : 1.42085194e-14
# votes : 1.4208385e-14
# tembo : 1.4208276e-14
# accompanying : 1.4208222e-14
# dsteffesenroncom : 1.4208222e-14
# gulf : 1.4207951e-14
# communicated : 1.42077605e-14
# kahn : 1.420768e-14
# weigh : 1.4207517e-14
# merchant : 1.4207463e-14
# feminine : 1.4207084e-14
# milepost : 1.4207029e-14
# gas : 1.4206867e-14
# passion : 1.4206731e-14
# favors : 1.420646e-14
# athletics : 1.4206271e-14
# cra : 1.4206108e-14
# image : 1.4206e-14
# drawing : 1.4205783e-14
# revival : 1.4205078e-14
# duty-free : 1.4205024e-14
# lift : 1.4204916e-14
# threat : 1.42047535e-14
# flies : 1.42047e-14
# governing : 1.4204646e-14
# amusing : 1.4203914e-14
# accomplishments : 1.4203914e-14
# requires : 1.42032365e-14
# kitchen : 1.42029926e-14
# eds : 1.4202884e-14
# lesbians : 1.4202586e-14
# shrank : 1.4202505e-14
# agreed : 1.4202316e-14
# emotions : 1.4202179e-14
# logical : 1.4201367e-14
# marshall : 1.4201286e-14
# medicine : 1.4200583e-14
# site : 1.4200365e-14
# studio : 1.420031e-14
# incense : 1.42002024e-14
# die : 1.4199661e-14
# style : 1.4199282e-14
# celli : 1.41989564e-14
# designers : 1.4198848e-14
# plant : 1.4198659e-14
# proportion : 1.419809e-14
# secretary : 1.41977655e-14
# greyhem : 1.41977105e-14
# jail : 1.41974945e-14
# humane : 1.41974945e-14
# shaw : 1.41973056e-14
# glance : 1.41972785e-14
# ground : 1.4197223e-14
# x-cc : 1.4197169e-14
# importance : 1.4197007e-14
# happening : 1.4196953e-14
# occurrences : 1.4196844e-14
# odds : 1.4196682e-14
# chased : 1.4196682e-14
# entrance : 1.4196493e-14
# ape : 1.419587e-14
# repair : 1.41957614e-14
# airport : 1.41956e-14
# amanda : 1.4195436e-14
# connecticut : 1.4194949e-14
# reclaimed : 1.4194787e-14
# ninety : 1.419476e-14
# husbands : 1.4194299e-14
# jean : 1.4194191e-14
# meant : 1.4193623e-14
# product : 1.4193541e-14
# embarrassed : 1.4193434e-14
# gap : 1.41931085e-14
# pollution : 1.41928925e-14
# gentleman : 1.4192729e-14
# jeff : 1.4192729e-14
# richardson : 1.4192512e-14
# receivedtue : 1.4191701e-14
# notable : 1.41913755e-14
# strategy : 1.4191214e-14
# assessing : 1.4191159e-14
# prevention : 1.4190672e-14
# gene : 1.4190617e-14
# wireless : 1.4190563e-14
# epr : 1.4190401e-14
# issue : 1.4190319e-14
# biology : 1.418986e-14
# confronted : 1.418986e-14
# czech : 1.41896975e-14
# prospects : 1.4189643e-14
# miller : 1.4189291e-14
# starts : 1.4189102e-14
# proximal : 1.418894e-14
# wind : 1.4188831e-14
# posting : 1.4188669e-14
# malaysia : 1.4188615e-14
# casinos : 1.4188588e-14
# success : 1.4188588e-14
# query : 1.4188453e-14
# frowned : 1.4188453e-14
# melody : 1.4188399e-14
# hewlett : 1.4188317e-14
# sum : 1.4188236e-14
# discontinued : 1.4187993e-14
# cram : 1.4187803e-14
# delivering : 1.4187749e-14
# regardless : 1.418737e-14
# k : 1.4186505e-14
# days : 1.4186423e-14
# deliberations : 1.4186342e-14
# pleasure : 1.4186153e-14
# escaped : 1.4185693e-14
# infrastructure : 1.4185693e-14
# lowering : 1.41855835e-14
# fetus : 1.4185531e-14
# paying : 1.4184448e-14
# venkatarmani : 1.4184259e-14
# withdraw : 1.418415e-14
# httptinyurlcomcrgl : 1.4183853e-14
# prove : 1.4183637e-14
# worn : 1.418361e-14
# catholic : 1.4182825e-14
# vincejkaminskienroncom : 1.4182014e-14
# eliminated : 1.418177e-14
# handguns : 1.41815e-14
# blush : 1.4181229e-14
# aspects : 1.41811476e-14
# ecology : 1.41811476e-14
# programme : 1.4180336e-14
# profound : 1.4180309e-14
# implies : 1.4180066e-14
# upset : 1.4179931e-14
# fertile : 1.4179849e-14
# business : 1.4179795e-14
# hole : 1.4179309e-14
# pentagon : 1.4179309e-14
# govern : 1.41792545e-14
# enemies : 1.41792e-14
# sucked : 1.4179093e-14
# firmly : 1.4179011e-14
# floor : 1.41788496e-14
# wait : 1.4178822e-14
# qualities : 1.417866e-14
# sgml : 1.4178497e-14
# running : 1.41778204e-14
# route : 1.41776044e-14
# leftmotorop : 1.4177253e-14
# wine : 1.4177172e-14
# complaining : 1.4177118e-14
# railings : 1.4176983e-14
# necessary : 1.417655e-14
# ducked : 1.4176253e-14
# nestpatrolage : 1.4175901e-14
# informal : 1.4175766e-14
# im : 1.41755224e-14
# valdez : 1.4175495e-14
# min : 1.4175415e-14
# placodes : 1.4175361e-14
# vice : 1.41751175e-14
# emerges : 1.417509e-14
# victoria : 1.4175035e-14
# welfare : 1.4174955e-14
# blasts : 1.4174928e-14
# costly : 1.4174117e-14
# postal : 1.4174009e-14
# introduce : 1.4173873e-14
# galleries : 1.4173523e-14
# chairman : 1.41734955e-14
# commodore : 1.4172981e-14
# pieces : 1.4172981e-14
# unfortunate : 1.4172792e-14
# creationism : 1.4172117e-14
# '' : 1.4172008e-14
# self-confidence : 1.4171954e-14
# rudiments : 1.4171928e-14
# practices : 1.4171575e-14
# willing : 1.4171359e-14
# breeze : 1.4170143e-14
# legend : 1.41700625e-14
# mm-hmm : 1.41698736e-14
# guatemala : 1.4169522e-14
# arrived : 1.4169359e-14
# thinks : 1.416817e-14
# craft : 1.4168008e-14
# photo : 1.4167928e-14
# inland : 1.416763e-14
# inversion : 1.4167251e-14
# pm : 1.4166819e-14
# vegas : 1.4166198e-14
# enable : 1.4166117e-14
# corner : 1.4166009e-14
# sh- : 1.4165982e-14
# northwest : 1.4165847e-14
# dangling : 1.4164928e-14
# cote : 1.4164496e-14
# upgrade : 1.416436e-14
# possession : 1.4164334e-14
# armed : 1.41641705e-14
# wiretaps : 1.41641705e-14
# sake : 1.4164091e-14
# soiled : 1.4164009e-14
# scrambled : 1.4163956e-14
# amazed : 1.4163901e-14
# tall : 1.4163847e-14
# kraken's : 1.416382e-14
# silently : 1.41637665e-14
# exclamation : 1.4163523e-14
# smelled : 1.41633065e-14
# minority : 1.4162497e-14
# gang : 1.4162497e-14
# achievement : 1.416174e-14
# grill : 1.4161713e-14
# campaigns : 1.4161363e-14
# dec : 1.4160822e-14
# wolves : 1.4160768e-14
# side : 1.416066e-14
# cried : 1.4160499e-14
# discovered : 1.41604164e-14
# spirits : 1.4160362e-14
# highlight : 1.4159445e-14
# dame : 1.4159229e-14
# leads : 1.4159094e-14
# muttered : 1.4158823e-14
# pretending : 1.4158769e-14
# somewhat : 1.4158554e-14
# imf : 1.41584446e-14
# dignity : 1.4158338e-14
# hope : 1.415823e-14
# rubber : 1.415823e-14
# marque : 1.415823e-14
# twenty-five : 1.4158175e-14
# mission : 1.4158013e-14
# placement : 1.4157473e-14
# blusparrow : 1.4156555e-14
# deformation : 1.4155907e-14
# financing : 1.4155745e-14
# stephen : 1.4155691e-14
# elevator : 1.4155583e-14
# conservatives : 1.4155312e-14
# mercury : 1.4155287e-14
# americas : 1.4154341e-14
# colleges : 1.4154233e-14
# regularly : 1.4154071e-14
# tortuga : 1.4153963e-14
# sherry : 1.41539095e-14
# constructions : 1.4153748e-14
# combination : 1.41536385e-14
# concert : 1.4153558e-14
# investigating : 1.4153369e-14
# hold : 1.41532616e-14
# plug : 1.4153153e-14
# henry : 1.4152938e-14
# spirit : 1.4152614e-14
# forces : 1.4152559e-14
# length : 1.4152559e-14
# roger : 1.4152559e-14
# recording : 1.4152559e-14
# ischemia : 1.4152452e-14
# authorizes : 1.4152425e-14
# rangers : 1.4151641e-14
# laurent : 1.4151561e-14
# assured : 1.4151372e-14
# developing : 1.4151237e-14
# screen : 1.415121e-14
# sheikh : 1.4151182e-14
# shield : 1.4150886e-14
# instance : 1.41502105e-14
# ken : 1.4150022e-14
# output : 1.4149618e-14
# precisely : 1.41495355e-14
# photoip : 1.4149104e-14
# starving : 1.414897e-14
# antibody : 1.4148404e-14
# calibrate : 1.41482946e-14
# tsim : 1.41478905e-14
# mills : 1.41476745e-14
# den : 1.41466225e-14
# negotiated : 1.4146595e-14
# absolute : 1.4146406e-14
# schema : 1.41461905e-14
# pwaiting : 1.4145651e-14
# assign : 1.4145165e-14
# simply : 1.4145111e-14
# contour : 1.4144734e-14
# documentary : 1.4144571e-14
# joe's : 1.4144329e-14
# restroom : 1.41438705e-14
# goodbye : 1.4143816e-14
# uk : 1.414333e-14
# twist : 1.41432225e-14
# sightseeing : 1.41430065e-14
# electronics : 1.4142575e-14
# useless : 1.4142413e-14
# center : 1.414236e-14
# janices : 1.4142116e-14
# mississippi : 1.41419545e-14
# tremendous : 1.4141874e-14
# acting : 1.4141847e-14
# fruits : 1.41417665e-14
# equatorial : 1.4141281e-14
# almost : 1.4141011e-14
# palladio : 1.4140957e-14
# till : 1.4140687e-14
# bench : 1.4140418e-14
# winery : 1.4140229e-14
# fold : 1.4139824e-14
# extraordinarily : 1.4139716e-14
# fixing : 1.41394464e-14
# pthere : 1.4139366e-14
# partying : 1.4139285e-14
# thickness : 1.41390145e-14
# alive : 1.4138853e-14
# r : 1.4137775e-14
# outlet : 1.413772e-14
# pausing : 1.4136696e-14
# shipped : 1.4136454e-14
# peak : 1.4136264e-14
# extract : 1.4135941e-14
# bosses : 1.4135941e-14
# ios : 1.4135239e-14
# slow : 1.4135187e-14
# protected : 1.41349165e-14
# herb : 1.41347005e-14
# rachel : 1.41347005e-14
# seemingly : 1.4134431e-14
# files : 1.4134135e-14
# becoming : 1.4133837e-14
# simvastatin : 1.4133837e-14
# separated : 1.41334605e-14
# genius : 1.4132949e-14
# requirements : 1.4132652e-14
# trust : 1.4132328e-14
# cassandra : 1.4132328e-14
# exclaimed : 1.4131897e-14
# pain : 1.4131305e-14
# suit : 1.4131196e-14
# inform : 1.4131196e-14
# dense : 1.4130764e-14
# breakdowns : 1.41303874e-14
# certification : 1.4129687e-14
# david's : 1.41296336e-14
# pass : 1.4129418e-14
# highlighted : 1.4129095e-14
# pounding : 1.4128987e-14
# training : 1.41287704e-14
# remote : 1.4128124e-14
# ip : 1.4128097e-14
# activist : 1.4127855e-14
# warn : 1.4127747e-14
# relied : 1.4127451e-14
# follow : 1.41271535e-14
# viability : 1.4126345e-14
# loan : 1.4125376e-14
# routines : 1.4125294e-14
# pillard : 1.4125267e-14
# doings : 1.4124621e-14
# freelance : 1.41243515e-14
# guessed : 1.41229505e-14
# continued : 1.4122735e-14
# talks : 1.4122197e-14
# sound : 1.412155e-14
# hopefully : 1.412155e-14
# liz : 1.4121497e-14
# color : 1.4121281e-14
# eastern : 1.4121012e-14
# jimmy : 1.4120824e-14
# unexpected : 1.41207965e-14
# protocol : 1.4120526e-14
# challenging : 1.4120474e-14
# finer : 1.4120257e-14
# shovel : 1.41201765e-14
# b : 1.4119907e-14
# journalism : 1.4119772e-14
# precious : 1.4119665e-14
# cooperation : 1.4119665e-14
# mouse : 1.41192345e-14
# shadows : 1.4118884e-14
# agree : 1.4118803e-14
# tupelo : 1.4118481e-14
# answered : 1.4118454e-14
# lovinglife : 1.4118319e-14
# violations : 1.4118104e-14
# stunning : 1.41180496e-14
# featured : 1.41180224e-14
# teacher : 1.4117834e-14
# within : 1.4117592e-14
# country's : 1.4117485e-14
# shower : 1.4117133e-14
# shingle : 1.4116918e-14
# historical : 1.4116703e-14
# landing : 1.41166486e-14
# dream : 1.4116245e-14
# preservation : 1.4116218e-14
# bonfire : 1.41160565e-14
# convince : 1.41156796e-14
# ankles : 1.41156796e-14
# n- : 1.4115519e-14
# signifies : 1.411541e-14
# upstairs : 1.411533e-14
# melvin : 1.4115142e-14
# knee : 1.411498e-14
# assembly : 1.411455e-14
# sanjay : 1.4114173e-14
# ory : 1.4114038e-14
# particularly : 1.4114038e-14
# brothers : 1.4113581e-14
# cofactor : 1.4113526e-14
# baggy : 1.4112934e-14
# react : 1.41127725e-14
# flamingo : 1.4112746e-14
# growth : 1.4112072e-14
# chicago : 1.4111803e-14
# employment : 1.41115875e-14
# presidents : 1.411132e-14
# indiana : 1.4111265e-14
# politically : 1.4111185e-14
# blade : 1.4110943e-14
# width : 1.411078e-14
# dim : 1.411078e-14
# brian : 1.4110458e-14
# surprised : 1.4110136e-14
# ginsburg : 1.4110081e-14
# anne : 1.41098655e-14
# equity : 1.4109623e-14
# calm : 1.4109031e-14
# lobster : 1.4108466e-14
# toy : 1.4108466e-14
# depths : 1.4108412e-14
# pis : 1.41081435e-14
# posterior : 1.4107659e-14
# typically : 1.4107497e-14
# tweets : 1.4107444e-14
# revascularization : 1.4107282e-14
# project : 1.4107282e-14
# stepped : 1.4106879e-14
# thorndike : 1.4106663e-14
# cm : 1.4106582e-14
# guard : 1.4106529e-14
# took : 1.410634e-14
# adjoining : 1.4106098e-14
# gasket : 1.4105668e-14
# rotate : 1.410556e-14
# participate : 1.410556e-14
# philippines : 1.4105265e-14
# pregnancy : 1.4104915e-14
# outline : 1.4104645e-14
# pressures : 1.4104645e-14
# algorithm : 1.4104593e-14
# hunchback : 1.4104376e-14
# operation : 1.41039185e-14
# compromise : 1.4103838e-14
# sleek : 1.4103463e-14
# website : 1.4103408e-14
# promises : 1.41031934e-14
# invention : 1.4103031e-14
# pgreat : 1.4102493e-14
# whereas : 1.4102143e-14
# listened : 1.41020084e-14
# temptation : 1.4101956e-14
# conserve : 1.4101929e-14
# sunday : 1.4101793e-14
# trusted : 1.4101768e-14
# digits : 1.4101471e-14
# note : 1.4101364e-14
# modern : 1.4101203e-14
# warned : 1.4101149e-14
# consensus : 1.4101041e-14
# frustrated : 1.4101041e-14
# fell : 1.4101041e-14
# oxford : 1.4100826e-14
# someone : 1.4100665e-14
# ampm : 1.4100315e-14
# contains : 1.4100019e-14
# hughes : 1.4099481e-14
# casual : 1.4099455e-14
# unsubscribe : 1.4099212e-14
# horses : 1.4099185e-14
# worker : 1.4099158e-14
# brings : 1.4099024e-14
# any : 1.4098917e-14
# innocent : 1.40981375e-14
# branch : 1.4097894e-14
# inspiring : 1.4097867e-14
# ourselves : 1.4097815e-14
# procedures : 1.4097277e-14
# lifts : 1.4096604e-14
# tokaminski : 1.4096094e-14
# neither : 1.4096012e-14
# forage : 1.4095959e-14
# processing : 1.4095556e-14
# pannesleyriskwaterscom : 1.40955015e-14
# settlers : 1.4095448e-14
# impact : 1.4094856e-14
# displacements : 1.4094641e-14
# panty : 1.40940235e-14
# agencies : 1.4093943e-14
# tissue : 1.4093728e-14
# addressed : 1.4093566e-14
# mcclelland : 1.40934585e-14
# spec : 1.40932976e-14
# n-alkene : 1.4093082e-14
# halts : 1.4092007e-14
# audubon : 1.4091524e-14
# attitude : 1.4091469e-14
# highly : 1.4091469e-14
# societies : 1.40910665e-14
# filled : 1.4090771e-14
# occasionally : 1.4090663e-14
# connected : 1.409061e-14
# objectives : 1.40903406e-14
# artist : 1.4090233e-14
# asheville : 1.4090045e-14
# disappointing : 1.4090018e-14
# swap : 1.4089803e-14
# subtract : 1.4089749e-14
# hydroxyl : 1.4089749e-14
# limitation : 1.40895875e-14
# contributions : 1.4089534e-14
# wade : 1.4089534e-14
# several : 1.408889e-14
# alongside : 1.4088836e-14
# corporation : 1.4088836e-14
# shelters : 1.4088352e-14
# allowances : 1.40881374e-14
# priscilla : 1.40881374e-14
# promote : 1.40881374e-14
# blackbirds : 1.4087976e-14
# fragile : 1.4087922e-14
# lessons : 1.4087922e-14
# g : 1.4087815e-14
# varieties : 1.40877605e-14
# nobody : 1.4087117e-14
# marketers : 1.4086794e-14
# intentional : 1.4086498e-14
# assumptions : 1.4086417e-14
# tentacle : 1.4086256e-14
# ow : 1.4086203e-14
# parser : 1.4086176e-14
# embryo : 1.4086068e-14
# unknown : 1.4085693e-14
# publicly : 1.40850746e-14
# tag : 1.408502e-14
# certified : 1.40834084e-14
# raises : 1.4083355e-14
# health-care : 1.4082844e-14
# spectra : 1.4082764e-14
# passes : 1.4082549e-14
# geek : 1.4082549e-14
# shakespeare : 1.4082281e-14
# couple : 1.4081502e-14
# washington : 1.40812595e-14
# endoderm : 1.4081099e-14
# announcement : 1.4080508e-14
# deposited : 1.40801855e-14
# psigning : 1.40800245e-14
# concur : 1.4079675e-14
# posed : 1.4079649e-14
# industries : 1.4079594e-14
# custom : 1.4079327e-14
# safer : 1.4078708e-14
# obscure : 1.407852e-14
# euh : 1.4078279e-14
# comey : 1.4077581e-14
# moving : 1.4077554e-14
# magic : 1.4077017e-14
# nwf : 1.4077017e-14
# footage : 1.407648e-14
# microsoft : 1.4076104e-14
# it'll : 1.4075889e-14
# snakes : 1.4075622e-14
# cox : 1.407495e-14
# disclosed : 1.407452e-14
# nest : 1.40741715e-14
# deepest : 1.4073903e-14
# choices : 1.40736074e-14
# rustic : 1.407342e-14
# opened : 1.4073392e-14
# closer : 1.4073365e-14
# forwarded : 1.4073259e-14
# enrollment : 1.4072776e-14
# todayp : 1.4072694e-14
# nearby : 1.4071917e-14
# allan : 1.4071782e-14
# bits : 1.4071702e-14
# aunido : 1.4071702e-14
# undertaken : 1.4071648e-14
# pleasant : 1.40714865e-14
# formation : 1.4071058e-14
# publication : 1.4070736e-14
# continuing : 1.4070494e-14
# fly : 1.4070333e-14
# vkaminsenroncom : 1.4069662e-14
# big : 1.40695815e-14
# accordance : 1.4069447e-14
# deeper : 1.4069072e-14
# renewed : 1.4068965e-14
# embellishment : 1.4068938e-14
# subsidence : 1.4068696e-14
# insurance : 1.4068696e-14
# difficulty : 1.4068642e-14
# aluminum : 1.40683465e-14
# x-from : 1.40674885e-14
# steepened : 1.4067193e-14
# confusing : 1.406706e-14
# negotiate : 1.4066764e-14
# currently : 1.4066603e-14
# cc : 1.4066228e-14
# kevinscottonlinemailboxnet : 1.4066173e-14
# label : 1.4065879e-14
# grown : 1.4065503e-14
# why : 1.4065449e-14
# faculty : 1.4065316e-14
# apologized : 1.4065155e-14
# winner : 1.4064993e-14
# multi-service : 1.406392e-14
# traveled : 1.4063813e-14
# signals : 1.4063759e-14
# b- : 1.4063651e-14
# scream : 1.4063598e-14
# authenticity : 1.40631694e-14
# fibroblasts : 1.4062633e-14
# dunes : 1.40623105e-14
# spending : 1.4061881e-14
# finger : 1.4061076e-14
# gold : 1.4060487e-14
# loves : 1.4060111e-14
# ne : 1.4059469e-14
# delivery : 1.4059388e-14
# httpwwwworgpeopleraggett : 1.4059281e-14
# save : 1.4058717e-14
# excellence : 1.4058235e-14
# miss : 1.40580195e-14
# hey : 1.4057914e-14
# integrity : 1.4057753e-14
# gov't : 1.4057753e-14
# convenience : 1.40575375e-14
# palaces : 1.40571614e-14
# sept : 1.40570556e-14
# atheist : 1.4056707e-14
# kim : 1.40566795e-14
# encourage : 1.4056251e-14
# meet : 1.4056143e-14
# recognize : 1.4056143e-14
# inviting : 1.4056063e-14
# rear : 1.4055982e-14
# tokhtakhounov's : 1.40558214e-14
# poker : 1.4055769e-14
# prosperity : 1.40553395e-14
# clothes : 1.4054884e-14
# arched : 1.405432e-14
# lens : 1.4054266e-14
# sought : 1.4053784e-14
# ireland : 1.4053544e-14
# possibilities : 1.4053463e-14
# bla : 1.4052847e-14
# hell : 1.4052766e-14
# conspiracy : 1.405239e-14
# one-third : 1.405239e-14
# wineries : 1.4051855e-14
# approve : 1.4051586e-14
# endorsement : 1.4051479e-14
# mansion : 1.40506215e-14
# facilities : 1.4050006e-14
# pill : 1.4049871e-14
# fails : 1.4049818e-14
# er : 1.404971e-14
# claim : 1.404963e-14
# netherlands : 1.4049175e-14
# mom : 1.4049067e-14
# struggled : 1.4048799e-14
# surface : 1.4048693e-14
# concerned : 1.4048424e-14
# constructed : 1.4048344e-14
# debated : 1.4048317e-14
# location : 1.4047835e-14
# stephens : 1.4047566e-14
# fix : 1.4047459e-14
# hes : 1.4047379e-14
# palestine : 1.4047353e-14
# occasion : 1.4047299e-14
# pushing : 1.4047138e-14
# electronic : 1.4046923e-14
# heroes : 1.4046844e-14
# old : 1.4046281e-14
# dealing : 1.4046146e-14
# houston : 1.4046013e-14
# suite : 1.4045905e-14
# tandem : 1.404537e-14
# demanding : 1.404537e-14
# seedbombing : 1.40453165e-14
# happenings : 1.40451564e-14
# fig : 1.4045049e-14
# nancy : 1.40449955e-14
# hired : 1.40447e-14
# varying : 1.4044674e-14
# pennsylvania : 1.4044539e-14
# pains : 1.40444585e-14
# accounts : 1.40434675e-14
# light : 1.4043281e-14
# republicans : 1.4043281e-14
# mechanical : 1.404304e-14
# records : 1.4042852e-14
# dc : 1.4042558e-14
# poorly : 1.4042343e-14
# privileges : 1.4042262e-14
# mapping : 1.4042101e-14
# thorough : 1.4040843e-14
# attract : 1.4040174e-14
# watched : 1.4039959e-14
# thu : 1.4039638e-14
# beach : 1.4039531e-14
# valid : 1.4039504e-14
# abbreviated : 1.4039316e-14
# allah : 1.4039291e-14
# harvey : 1.4038379e-14
# controls : 1.4038299e-14
# duty : 1.4038138e-14
# nc : 1.40369605e-14
# will's : 1.4036639e-14
# dealings : 1.4036211e-14
# stomach : 1.4036078e-14
# math-erb : 1.403605e-14
# existing : 1.4035621e-14
# hardy : 1.4035408e-14
# refugees : 1.4034712e-14
# paid : 1.4034712e-14
# fallacy : 1.403423e-14
# ceo : 1.4033829e-14
# boom : 1.40337215e-14
# surrounding : 1.403348e-14
# spears : 1.4033052e-14
# criticized : 1.4032998e-14
# cut : 1.4031955e-14
# normally : 1.40319275e-14
# proudly : 1.4031071e-14
# medical : 1.4030804e-14
# enactment : 1.40306705e-14
# similarly : 1.4030616e-14
# count : 1.4030536e-14
# coalitions : 1.4030161e-14
# thrown : 1.4030161e-14
# local : 1.4029974e-14
# foraging : 1.4029734e-14
# dragged : 1.40292254e-14
# oregon : 1.4029171e-14
# customary : 1.4029037e-14
# kissed : 1.40289315e-14
# sony : 1.4028797e-14
# webmail : 1.4028771e-14
# rite : 1.4028182e-14
# talented : 1.40276466e-14
# translation : 1.4026898e-14
# particular : 1.4026656e-14
# included : 1.4026523e-14
# pools : 1.4026523e-14
# collaboration : 1.4026416e-14
# casket : 1.4026416e-14
# siting : 1.40262015e-14
# february : 1.4026149e-14
# guess : 1.4025935e-14
# bye-bye : 1.40258805e-14
# aboard : 1.402556e-14
# floats : 1.4025265e-14
# lover : 1.40251055e-14
# evaluation : 1.4025078e-14
# left : 1.4024864e-14
# departments : 1.40247565e-14
# penny : 1.4024543e-14
# fourth : 1.40239815e-14
# competitors : 1.4023768e-14
# institutional : 1.40234995e-14
# fine : 1.4023446e-14
# pulled : 1.4023152e-14
# wolf : 1.4022938e-14
# solomon : 1.4022778e-14
# license : 1.4022536e-14
# students : 1.4022483e-14
# fundamental : 1.4022377e-14
# solution : 1.40222425e-14
# alaskans : 1.4022083e-14
# alexander : 1.4021815e-14
# nowhere : 1.4021761e-14
# fresh : 1.4021548e-14
# edinburgh : 1.4021521e-14
# biopsy : 1.4021253e-14
# filmmaking : 1.4020906e-14
# machinery : 1.4020637e-14
# chambers : 1.40203435e-14
# genial : 1.401997e-14
# ruins : 1.4019729e-14
# hence : 1.4019247e-14
# rabbit : 1.4019194e-14
# emphasize : 1.4019033e-14
# talked : 1.4019008e-14
# participating : 1.4018927e-14
# log : 1.401882e-14
# indicator : 1.4018686e-14
# protective : 1.4018605e-14
# wells : 1.4018232e-14
# wetlands : 1.4017803e-14
# sharp : 1.4017644e-14
# labeling : 1.401751e-14
# fund-raising : 1.401743e-14
# notebook : 1.4017322e-14
# launch : 1.4017322e-14
# exaggeration : 1.4017216e-14
# tells : 1.4017136e-14
# reporter : 1.4017109e-14
# claws : 1.4016948e-14
# touch : 1.4016734e-14
# perpetual : 1.401652e-14
# prudent : 1.4015986e-14
# situations : 1.4015798e-14
# works : 1.4015719e-14
# prevent : 1.4015451e-14
# delhi : 1.4014703e-14
# julia : 1.40145955e-14
# giant : 1.4014329e-14
# domestic : 1.4014168e-14
# u : 1.401342e-14
# borrowers : 1.4013312e-14
# usage : 1.4013259e-14
# choosing : 1.4013099e-14
# loses : 1.4013045e-14
# regulated : 1.4012992e-14
# buyer : 1.4012992e-14
# learning : 1.4012779e-14
# double : 1.4012725e-14
# pants : 1.4012698e-14
# assigned : 1.4012351e-14
# block : 1.4012351e-14
# portuguese : 1.4012164e-14
# gather : 1.4012056e-14
# horror : 1.4012031e-14
# diversity : 1.4010453e-14
# employ : 1.4010266e-14
# horrible : 1.4010213e-14
# dad : 1.4009678e-14
# charged : 1.4009678e-14
# nelson : 1.4009625e-14
# argument : 1.400925e-14
# bad : 1.400877e-14
# crashed : 1.4008449e-14
# largely : 1.4008182e-14
# womans : 1.4007968e-14
# civilians : 1.4007807e-14
# lovers : 1.4007754e-14
# jerry : 1.4007166e-14
# shot : 1.4006632e-14
# codp : 1.4006606e-14
# reuters : 1.4006579e-14
# clever : 1.4005911e-14
# ill : 1.4005858e-14
# warming : 1.4005456e-14
# correlated : 1.4005323e-14
# victories : 1.4005216e-14
# overview : 1.4004922e-14
# seed : 1.4004763e-14
# find : 1.4004602e-14
# cuz : 1.4004602e-14
# familiar : 1.4004549e-14
# disturbing : 1.4004495e-14
# delight : 1.40042015e-14
# crew : 1.4004121e-14
# destroy : 1.4003908e-14
# price : 1.4003908e-14
# adoption : 1.400316e-14
# s : 1.40028395e-14
# pea : 1.4002759e-14
# pstill : 1.4002519e-14
# melon : 1.4002331e-14
# eager : 1.40022525e-14
# metallic : 1.4002145e-14
# ad : 1.4002119e-14
# greeks : 1.4001717e-14
# appreciated : 1.400153e-14
# landed : 1.3999394e-14
# torture : 1.3999127e-14
# dow : 1.3998887e-14
# amc : 1.3998647e-14
# teach : 1.3998379e-14
# drink : 1.3998139e-14
# presidency : 1.3998112e-14
# faithful : 1.3997899e-14
# principle : 1.39978725e-14
# climate : 1.3997766e-14
# consistency : 1.3997606e-14
# mortal : 1.3997498e-14
# signal : 1.3997391e-14
# enacted : 1.3997071e-14
# trunks : 1.3997018e-14
# attending : 1.3997018e-14
# affairs : 1.399691e-14
# rough : 1.3995844e-14
# destination : 1.3995817e-14
# sensational : 1.3995683e-14
# goodwill's : 1.39956025e-14
# erection : 1.3995363e-14
# confirmed : 1.3995255e-14
# wooden : 1.3994722e-14
# slipping : 1.3994562e-14
# furniture : 1.3994402e-14
# assumed : 1.3994162e-14
# preserved : 1.39939745e-14
# sinuous : 1.3993602e-14
# depended : 1.3993334e-14
# fallen : 1.3993282e-14
# ap : 1.39932545e-14
# slowly : 1.3993121e-14
# congratulations : 1.3992319e-14
# movie : 1.3992294e-14
# automatic : 1.3991893e-14
# cowboys : 1.3990879e-14
# borders : 1.3990051e-14
# optional : 1.3988985e-14
# jan : 1.3988904e-14
# nintendo : 1.3988878e-14
# snow : 1.39888245e-14
# cat : 1.3988718e-14
# illiteracy : 1.3988371e-14
# women's : 1.398757e-14
# followers : 1.3987517e-14
# napa : 1.3987169e-14
# thomas : 1.398693e-14
# metals : 1.398645e-14
# honest : 1.3985543e-14
# markets : 1.3985436e-14
# bankruptcy : 1.39852754e-14
# replacing : 1.3985063e-14
# stimulate : 1.3984822e-14
# grammar : 1.398469e-14
# otc : 1.398437e-14
# themselves : 1.3984075e-14
# maine : 1.3983942e-14
# atorvastatin : 1.3983276e-14
# routinely : 1.3982662e-14
# attention : 1.3982555e-14
# draws : 1.39823955e-14
# magna : 1.39818085e-14
# signaling : 1.3981755e-14
# werent : 1.3981435e-14
# steve : 1.3981356e-14
# demosthenes : 1.3981222e-14
# epic : 1.3981142e-14
# affidavit : 1.3980768e-14
# players : 1.3980768e-14
# eyelids : 1.39806625e-14
# adam : 1.3980609e-14
# giselle : 1.3980582e-14
# wwf : 1.3980476e-14
# shorter : 1.39803694e-14
# curriculum : 1.3980262e-14
# downstream : 1.3980236e-14
# participation : 1.3980049e-14
# cream : 1.3980049e-14
# existed : 1.3979568e-14
# wedding : 1.3979303e-14
# monday : 1.397925e-14
# forum : 1.3979169e-14
# teabagging : 1.3979142e-14
# woman : 1.3978876e-14
# signing : 1.3978715e-14
# hearts : 1.39785026e-14
# dry : 1.39780765e-14
# town : 1.3978022e-14
# graceful : 1.3977703e-14
# commit : 1.39776225e-14
# founder : 1.3977595e-14
# backyard : 1.3977436e-14
# truth : 1.39773294e-14
# threshold : 1.3977302e-14
# thereby : 1.39770355e-14
# clockwise : 1.3976796e-14
# cook : 1.39767424e-14
# subset : 1.3976689e-14
# pgot : 1.397653e-14
# oklahoma : 1.3976449e-14
# spent : 1.3976156e-14
# isolated : 1.3975569e-14
# cabin : 1.3975011e-14
# bachelor : 1.3974877e-14
# pride : 1.39746376e-14
# rightmiddenip : 1.3973704e-14
# pointed : 1.39734915e-14
# inability : 1.3973464e-14
# macau : 1.3973171e-14
# assessments : 1.397301e-14
# int : 1.39729045e-14
# exaggerations : 1.39727444e-14
# hear : 1.3972452e-14
# theory : 1.3972424e-14
# routes : 1.3972212e-14
# station : 1.3972132e-14
# roof : 1.3972104e-14
# pope : 1.39717585e-14
# reality : 1.3971385e-14
# carter : 1.3971145e-14
# eternal : 1.39704e-14
# attorneys : 1.39703465e-14
# computer : 1.3970107e-14
# situ : 1.3969307e-14
# exchange : 1.3969227e-14
# saxenian : 1.3968907e-14
# belief-net : 1.396888e-14
# dmem : 1.3968694e-14
# firms : 1.3968587e-14
# gore : 1.3968481e-14
# paint : 1.3968267e-14
# synthesis : 1.3968267e-14
# perfectly : 1.3967762e-14
# directors : 1.3967362e-14
# governments : 1.3967309e-14
# ways : 1.39670956e-14
# corps : 1.3966616e-14
# trends : 1.3966563e-14
# rotation : 1.3966483e-14
# airborne : 1.396635e-14
# unlike : 1.3965551e-14
# captain : 1.3965338e-14
# applied : 1.3965018e-14
# ancestors : 1.3964858e-14
# especially : 1.3964432e-14
# engine : 1.3964192e-14
# hmm : 1.396406e-14
# incremental : 1.3963686e-14
# question : 1.3963633e-14
# eat : 1.3963393e-14
# palestinians : 1.3963127e-14
# x-folder : 1.3963074e-14
# scent : 1.3962648e-14
# questions : 1.39624886e-14
# rust : 1.3962274e-14
# shares : 1.3962249e-14
# polarization : 1.39621955e-14
# dare : 1.39621955e-14
# elimination : 1.3961155e-14
# praise : 1.396113e-14
# usually : 1.3960756e-14
# abbey : 1.3960544e-14
# hunt : 1.3959904e-14
# sighed : 1.3959798e-14
# ninth : 1.3959425e-14
# tom : 1.3959187e-14
# qaeda : 1.3959053e-14
# overhead : 1.3958919e-14
# instructions : 1.395884e-14
# sensing : 1.395876e-14
# specialized : 1.3958626e-14
# sticking : 1.395852e-14
# flicks : 1.3958308e-14
# h- : 1.3958201e-14
# fiction : 1.39579874e-14
# catalytic : 1.3957855e-14
# religion : 1.39577215e-14
# through : 1.3957668e-14
# minded : 1.3957616e-14
# she'll : 1.3957535e-14
# downtown : 1.3957376e-14
# wide : 1.3957295e-14
# surrounded : 1.3956976e-14
# catch : 1.3956497e-14
# nature : 1.39563645e-14
# teaparty : 1.3956311e-14
# mid-s : 1.3956018e-14
# bamboo : 1.39556445e-14
# inspire : 1.39553515e-14
# maybe : 1.3955167e-14
# ultimatum : 1.3955086e-14
# bells : 1.3954261e-14
# souter : 1.3953941e-14
# karthik : 1.3953675e-14
# jonson : 1.39530365e-14
# consignment : 1.395293e-14
# virus : 1.3952558e-14
# saddam : 1.3952318e-14
# countless : 1.39520785e-14
# went : 1.3951972e-14
# theodore : 1.3951866e-14
# monument : 1.39515195e-14
# legislative : 1.3951467e-14
# indigenous : 1.3951201e-14
# speed : 1.3951201e-14
# rolland : 1.3951041e-14
# awards : 1.39502955e-14
# huh : 1.3949711e-14
# catastrophe : 1.3949525e-14
# egypt : 1.3949525e-14
# neglect : 1.39490995e-14
# testimony : 1.3948619e-14
# doses : 1.3948301e-14
# aol : 1.3948301e-14
# pearls : 1.3948247e-14
# civilization : 1.3947289e-14
# ready : 1.394713e-14
# views : 1.3946652e-14
# yards : 1.3946331e-14
# hillary : 1.3945507e-14
# skilled : 1.3945215e-14
# horn : 1.3945029e-14
# limited : 1.3944736e-14
# reduce : 1.3944736e-14
# preceding : 1.3943566e-14
# futile : 1.3943033e-14
# who's : 1.39429805e-14
# slot : 1.3942236e-14
# ...
# foldersall : 1.30272354e-14
# police : 1.30271355e-14
# frequent : 1.3027061e-14
# defenders : 1.3026663e-14
# funded : 1.3025868e-14
# unregulated : 1.3025794e-14
# idiot : 1.3025521e-14
# html-math : 1.3025073e-14
# mayor : 1.30225895e-14
# calculate : 1.3021547e-14
# sensible : 1.3021447e-14
# engines : 1.3018765e-14
# creator : 1.3018714e-14
# considering : 1.3016629e-14
# timing : 1.30155625e-14
# ladder : 1.3014395e-14
# demon : 1.3013029e-14
# audience : 1.3012657e-14
# moodys : 1.30125835e-14
# into : 1.3012137e-14
# clan : 1.3011814e-14
# troubles : 1.3011714e-14
# bobby : 1.3008736e-14
# stepping : 1.3008092e-14
# notation : 1.3006901e-14
# disappearing : 1.3005462e-14
# dancer : 1.3004916e-14
# broaddrick's : 1.30041225e-14
# sent : 1.3003726e-14
# forward : 1.3002139e-14
# reductions : 1.3001296e-14
# crowds : 1.30007e-14
# indo-european : 1.3000403e-14
# astros : 1.3000253e-14
# outside : 1.2999956e-14
# exposure : 1.299956e-14
# priority : 1.2997874e-14
# spell : 1.2997774e-14
# operating : 1.2997031e-14
# surgery : 1.2996883e-14
# charge : 1.2996386e-14
# frankly : 1.2996336e-14
# performing : 1.29957665e-14
# transported : 1.2995147e-14
# senator : 1.2994378e-14
# pwatching : 1.2993857e-14
# widener : 1.2992073e-14
# bat : 1.2990364e-14
# victor : 1.2990364e-14
# laid : 1.2989695e-14
# sanctions : 1.2988753e-14
# rogers : 1.29874156e-14
# theyre : 1.2986995e-14
# eclectic : 1.2986723e-14
# born : 1.2985706e-14
# enforcement : 1.2983304e-14
# fu : 1.2982413e-14
# camera : 1.2982066e-14
# rowboat : 1.298167e-14
# devastating : 1.2981571e-14
# deep : 1.2981125e-14
# stanley : 1.298068e-14
# objects : 1.2978848e-14
# understood : 1.2978253e-14
# holidays : 1.2977858e-14
# kevin : 1.2977634e-14
# playing : 1.2975283e-14
# citizens : 1.2974838e-14
# attorney-client : 1.2973848e-14
# pagoda : 1.2972314e-14
# apprehension : 1.2972215e-14
# resist : 1.2970953e-14
# weird : 1.297073e-14
# gained : 1.2970235e-14
# brutal : 1.296791e-14
# goodwill : 1.29671935e-14
# steal : 1.29631625e-14
# gps : 1.29631125e-14
# army : 1.29627415e-14
# century : 1.2961827e-14
# raw : 1.29606654e-14
# undetected : 1.2959108e-14
# ho : 1.2958466e-14
# glutamate : 1.2958392e-14
# murray : 1.29583174e-14
# examination : 1.2958169e-14
# modest : 1.295807e-14
# feeding : 1.2956785e-14
# rings : 1.2955895e-14
# knowledge : 1.295466e-14
# taxpayer : 1.295377e-14
# cell : 1.2953473e-14
# lifetime : 1.2951102e-14
# luck : 1.2950164e-14
# anatrim : 1.2950164e-14
# opponents : 1.29491746e-14
# costs : 1.29491746e-14
# stories : 1.2948434e-14
# smooth : 1.2948361e-14
# stupid : 1.29470265e-14
# analog : 1.2943989e-14
# micro-level : 1.2942657e-14
# acceptable : 1.294157e-14
# commander : 1.2940978e-14
# gross : 1.2940089e-14
# cannon : 1.2938312e-14
# who'd : 1.2933772e-14
# create : 1.2933255e-14
# ed : 1.2932687e-14
# canadianwriter : 1.2930541e-14
# ultimate : 1.2930344e-14
# trigger : 1.2929777e-14
# bombing : 1.2928002e-14
# poses : 1.2926941e-14
# competitive : 1.2926399e-14
# voice : 1.2922578e-14
# notes : 1.2920113e-14
# ranging : 1.2920015e-14
# bigger : 1.2920015e-14
# snarls : 1.2918586e-14
# carolyn : 1.2917329e-14
# callahan : 1.2917254e-14
# paths : 1.29159734e-14
# dissemination : 1.2915875e-14
# kelly : 1.2913338e-14
# wonder : 1.291319e-14
# blonde : 1.2911688e-14
# darwinian : 1.2911343e-14
# laughs : 1.2910998e-14
# backup : 1.2910702e-14
# conflict : 1.2910653e-14
# causing : 1.2909225e-14
# cns : 1.2908782e-14
# violent : 1.2907231e-14
# filed : 1.2906566e-14
# winding : 1.2905114e-14
# technical : 1.2904992e-14
# where : 1.2904499e-14
# event : 1.2903711e-14
# leg : 1.2902874e-14
# ornament : 1.290226e-14
# wed : 1.2902013e-14
# perspective : 1.2901398e-14
# hurry : 1.2900315e-14
# planet : 1.2899848e-14
# ptalking : 1.28996265e-14
# venetian : 1.2899158e-14
# nak : 1.28986906e-14
# emphasizing : 1.2897461e-14
# horse : 1.2896822e-14
# pushed : 1.2896772e-14
# bear : 1.289569e-14
# bid : 1.2895272e-14
# print : 1.28951e-14
# troops : 1.2894608e-14
# w : 1.2892763e-14
# jake : 1.2892641e-14
# tax-deductible : 1.2892075e-14
# regiment : 1.28908945e-14
# teeth : 1.2890181e-14
# void : 1.2888608e-14
# dealt : 1.2888559e-14
# move : 1.2884921e-14
# clause : 1.2884627e-14
# haiti : 1.2884332e-14
# interchange : 1.288271e-14
# legislators : 1.288271e-14
# brazil : 1.28805725e-14
# scratched : 1.2880057e-14
# usa : 1.2876814e-14
# captured : 1.2876126e-14
# advisory : 1.2875144e-14
# hire : 1.2873965e-14
# cheers : 1.2873596e-14
# horizontal : 1.2871657e-14
# surprising : 1.2871067e-14
# i'm : 1.2870332e-14
# jackets : 1.2870086e-14
# remembered : 1.286714e-14
# creatures : 1.28665025e-14
# barriers : 1.286611e-14
# during : 1.2864442e-14
# warrior : 1.2862723e-14
# javamailevansthyme : 1.285951e-14
# oversight : 1.2858554e-14
# promptly : 1.2856101e-14
# calif : 1.2855439e-14
# risen : 1.2855317e-14
# totally : 1.2855121e-14
# eva : 1.2854874e-14
# characteristic : 1.2854263e-14
# evolved : 1.2853331e-14
# gass : 1.2852423e-14
# structure : 1.2850316e-14
# quota : 1.28502665e-14
# pressed : 1.28479135e-14
# nowp : 1.2847717e-14
# compiled : 1.2847178e-14
# columns : 1.2845709e-14
# hills : 1.2844484e-14
# car : 1.2843994e-14
# union : 1.28435775e-14
# reviewed : 1.2842989e-14
# boundary : 1.28425975e-14
# detected : 1.2842475e-14
# angeles : 1.28419605e-14
# supplement : 1.2841641e-14
# liberal : 1.2841152e-14
# describe : 1.2841005e-14
# cannibals : 1.2838948e-14
# ships : 1.2838508e-14
# asks : 1.28383115e-14
# newspaper : 1.2837822e-14
# annual : 1.2836768e-14
# regan : 1.28365234e-14
# environmental : 1.28331455e-14
# away : 1.2831849e-14
# title : 1.2830185e-14
# immortal : 1.2829376e-14
# barrier : 1.2828276e-14
# lungs : 1.282759e-14
# boulder : 1.2827199e-14
# gentle : 1.2827003e-14
# rexes : 1.2826612e-14
# supporter : 1.2823871e-14
# beg : 1.2821597e-14
# hellenistic : 1.2821476e-14
# floyd : 1.2821279e-14
# idioms : 1.2821084e-14
# numbered : 1.2818394e-14
# replies : 1.2818296e-14
# lundblade : 1.2813652e-14
# rational : 1.2813065e-14
# opposite : 1.2812527e-14
# charset : 1.2809497e-14
# complaint : 1.2807935e-14
# petitioners : 1.2807543e-14
# analysts : 1.2807104e-14
# draped : 1.2806615e-14
# detainees : 1.2806298e-14
# vehicle : 1.28062005e-14
# responsibilities : 1.28049545e-14
# germany : 1.2804026e-14
# bed-load : 1.28026345e-14
# tourism : 1.2798582e-14
# awk : 1.27984595e-14
# determination : 1.279575e-14
# elements : 1.2795139e-14
# savings : 1.2794676e-14
# emergent : 1.27931875e-14
# causeway : 1.2789479e-14
# unleashed : 1.2788552e-14
# hikes : 1.27885034e-14
# ottomans : 1.2788065e-14
# beast : 1.2787333e-14
# asked : 1.2786601e-14
# messenger : 1.2786113e-14
# copies : 1.2784601e-14
# there's : 1.2782602e-14
# yo : 1.2782578e-14
# cnn : 1.2781383e-14
# relaxing : 1.27809445e-14
# roots : 1.278031e-14
# narrow : 1.2777824e-14
# bella : 1.2777044e-14
# sale : 1.2776484e-14
# fibrosis : 1.2775752e-14
# crewmember : 1.2774826e-14
# items : 1.27747536e-14
# benefit : 1.2773072e-14
# listening : 1.2769905e-14
# versions : 1.2769784e-14
# collections : 1.27693215e-14
# marathon : 1.2767641e-14
# gunpowder : 1.27670074e-14
# claimed : 1.27634524e-14
# fenton : 1.2763356e-14
# homosexuals : 1.2763113e-14
# approximate : 1.27627714e-14
# deputy : 1.2762309e-14
# silence : 1.2760824e-14
# erosion : 1.27577096e-14
# chilean : 1.275676e-14
# finished : 1.275491e-14
# descended : 1.275406e-14
# look : 1.2750411e-14
# terrorism : 1.2750313e-14
# registry : 1.2748319e-14
# liberia : 1.2746326e-14
# hunting : 1.2745427e-14
# hca : 1.2744381e-14
# marks : 1.2744187e-14
# curves : 1.2740104e-14
# symptoms : 1.2739812e-14
# airplane : 1.2737552e-14
# ds : 1.273539e-14
# battery : 1.2730873e-14
# patroller : 1.2730315e-14
# message : 1.27289545e-14
# audubons : 1.2728469e-14
# ingredients : 1.2725823e-14
# yes : 1.27250226e-14
# chattahoochee : 1.2723833e-14
# saying : 1.272211e-14
# marcus : 1.27203385e-14
# con : 1.2719902e-14
# northern : 1.271573e-14
# fake : 1.2714615e-14
# stem : 1.2713791e-14
# visually : 1.27130624e-14
# remind : 1.2707099e-14
# tourists : 1.2707075e-14
# retention : 1.2706421e-14
# kingdom : 1.2705644e-14
# non-neural : 1.2703731e-14
# requests : 1.2701937e-14
# spanish : 1.2700363e-14
# lifestyle : 1.2698352e-14
# quash : 1.2696802e-14
# owen : 1.26901434e-14
# cakes : 1.2689031e-14
# adoptive : 1.2688934e-14
# didnt : 1.2688837e-14
# serological : 1.2684288e-14
# equation : 1.2683224e-14
# pursuit : 1.2682377e-14
# resulted : 1.2682353e-14
# th-century : 1.2681724e-14
# psyche : 1.2677564e-14
# famous : 1.2675944e-14
# fiesta : 1.2675534e-14
# swear : 1.2672536e-14
# devised : 1.2672174e-14
# fonts : 1.26720525e-14
# heroic : 1.2670167e-14
# veterans : 1.2668958e-14
# string : 1.26661555e-14
# owner : 1.2665867e-14
# bond : 1.26649e-14
# schuster : 1.26644165e-14
# delos : 1.2657751e-14
# throwing : 1.2657558e-14
# resulting : 1.2650873e-14
# default : 1.2650318e-14
# green : 1.2649884e-14
# switching : 1.26447204e-14
# sri : 1.2642648e-14
# awesome : 1.26404285e-14
# non-cns : 1.2638741e-14
# symbol : 1.2632668e-14
# likes : 1.263262e-14
# brainwashed : 1.2630428e-14
# gray : 1.2630018e-14
# lounge : 1.26278975e-14
# dutchman : 1.2627295e-14
# bathroom : 1.2624864e-14
# role : 1.2624359e-14
# registered : 1.2621564e-14
# mans : 1.2621348e-14
# genre : 1.2613911e-14
# california : 1.2612083e-14
# seconds : 1.2602609e-14
# digging : 1.2600662e-14
# wild : 1.2597467e-14
# membrane : 1.25970825e-14
# athletes : 1.259379e-14
# go-there : 1.258685e-14
# ietf : 1.2585531e-14
# wilson : 1.2583946e-14
# webinar : 1.2583634e-14
# k- : 1.25787866e-14
# down : 1.2577107e-14
# xmlnshttpwwwxcesorgschema : 1.2576892e-14
# deliberately : 1.2572382e-14
# proper : 1.2572119e-14
# answers : 1.2571375e-14
# nsc : 1.2569841e-14
# wise : 1.2565981e-14
# decrease : 1.2565526e-14
# shackles : 1.2564424e-14
# establish : 1.2562171e-14
# contemporary : 1.2556709e-14
# discussing : 1.2551968e-14
# trophy : 1.2551345e-14
# stanford : 1.2550077e-14
# muscle : 1.2548904e-14
# crisis : 1.2548784e-14
# kidney : 1.2548282e-14
# sheet : 1.2542922e-14
# publishing : 1.2532018e-14
# subroutine : 1.25249915e-14
# recipe : 1.25249915e-14
# namedave : 1.2522006e-14
# statistical : 1.2520215e-14
# reset : 1.2519594e-14
# abstract : 1.2519069e-14
# homosexual : 1.2515965e-14
# transparency : 1.25130526e-14
# sense : 1.2508614e-14
# quit : 1.2507398e-14
# saw : 1.250568e-14
# neck : 1.2501507e-14
# generally : 1.2498932e-14
# expenses : 1.2492259e-14
# mast : 1.2489685e-14
# kerjodando : 1.2489256e-14
# weak : 1.2488351e-14
# company : 1.2467622e-14
# ceremony : 1.246755e-14
# le : 1.2465457e-14
# bleeding : 1.2463366e-14
# roofs : 1.245733e-14
# sequences : 1.245443e-14
# hereby : 1.2453289e-14
# segment : 1.2450654e-14
# sits : 1.2445644e-14
# stretches : 1.24452645e-14
# postage : 1.243907e-14
# chronicle : 1.2429418e-14
# coronary : 1.2429134e-14
# harvested : 1.2427261e-14
# protocols : 1.2424156e-14
# ours : 1.2423682e-14
# wan : 1.24212655e-14
# reminds : 1.2420696e-14
# contribute : 1.2419086e-14
# sonoma : 1.241899e-14
# tracts : 1.2417475e-14
# doors : 1.24156285e-14
# experienced : 1.241416e-14
# occurrence : 1.2407673e-14
# owned : 1.2404976e-14
# express : 1.2403415e-14
# rural : 1.2403226e-14
# agreement : 1.2399062e-14
# whole : 1.23982576e-14
# slave : 1.23935294e-14
# arrow : 1.2387905e-14
# shortage : 1.2382684e-14
# racial : 1.237586e-14
# cole : 1.23710695e-14
# worst : 1.23708095e-14
# coastal : 1.2362201e-14
# network : 1.2361564e-14
# subexpressions : 1.2361423e-14
# researcher : 1.2356779e-14
# ligands : 1.234361e-14
# candidate : 1.2330857e-14
# editors : 1.2329775e-14
# release : 1.2329163e-14
# requested : 1.2327659e-14
# shed : 1.2321735e-14
# appropriations : 1.2320489e-14
# alright : 1.2316143e-14
# achieving : 1.2314968e-14
# experiment : 1.2311257e-14
# account : 1.23085805e-14
# steel : 1.2295113e-14
# technique : 1.2287728e-14
# subjectre : 1.22843765e-14
# mahoning : 1.2274399e-14
# investors : 1.2269039e-14
# cartel : 1.2244026e-14
# comment : 1.2234151e-14
# provision : 1.2230208e-14
# poof : 1.2229297e-14
# instruction : 1.2219273e-14
# robert : 1.22190855e-14
# manacles : 1.2212376e-14
# lips : 1.2204924e-14
# promise : 1.22036196e-14
# aclu : 1.22008735e-14
# sharply : 1.2173792e-14
# carry : 1.21708445e-14
# session : 1.2165924e-14
# ann : 1.2149321e-14
# vague : 1.2143552e-14
# stj-xls : 1.2137554e-14
# parker : 1.2129917e-14
# richard : 1.212492e-14
# comptroller : 1.2115812e-14
# mill : 1.2112023e-14
# marketing : 1.2085877e-14
# ortega : 1.20782265e-14
# messed : 1.2077605e-14
# falling : 1.2057349e-14
# pills : 1.2028614e-14
# needless : 1.2027489e-14
# matter : 1.2020334e-14
# admit : 1.2014581e-14
# outfielder : 1.194268e-14
# exercising : 1.1910014e-14
# pi've : 1.18890425e-14
# supervision : 1.1886072e-14
# switched : 1.1777098e-14
# pge : 1.1713385e-14
# disease : 1.1581979e-14
# themed : 1.1437442e-14
# relevant : 1.1420939e-14
# guidelines : 1.06273895e-14
# provide : 1.0146841e-14
# collection : 9.795453e-15
# powered : 9.65791e-15
# recent : 9.399071e-15
# comparable : 9.083987e-15
# reason : 8.7908095e-15
# detail : 8.666183e-15
# continuous : 8.24171e-15
# presented : 7.4576465e-15
# smaller : 7.273922e-15
# robust : 6.63097e-15
# its : 6.559244e-15
# may : 6.4487646e-15
# likely : 5.9011053e-15
# analysis : 5.4892e-15
# variable : 5.4188573e-15
# last : 5.033715e-15
# every : 4.613773e-15
# even : 4.599942e-15
# other : 4.4607982e-15
# successful : 4.40634e-15
# peers : 4.3533436e-15
# rather : 4.316863e-15
# time : 4.207415e-15
# article : 3.7922334e-15
# be : 3.5191168e-15
# however : 3.4546071e-15
# ensure : 3.4320144e-15
# key : 3.2309494e-15
# due : 3.1103046e-15
# examining : 3.0328813e-15
# conclusions : 2.9813652e-15
# active : 2.968564e-15
# present : 2.9439795e-15
# ranges : 2.8431243e-15
# they : 2.8199554e-15
# elsewhere : 2.7652121e-15
# often : 2.3685519e-15
# estimate : 2.276572e-15
# amount : 2.1420462e-15
# available : 2.0928247e-15
# inconsistent : 2.0627613e-15
# studied : 1.7270227e-15
# extensive : 1.7113423e-15
# confidence : 1.4064342e-15
# defining : 1.3556332e-15
# against : 1.3446115e-15
# disappeared : 1.2701131e-15
# distinguish : 1.1122713e-15
# incomplete : 1.1102916e-15
# depression : 1.1066171e-15
# little : 1.0482116e-15
# discussion : 1.044169e-15
# small : 8.516377e-16
# treatment : 8.3587625e-16
# extremely : 7.906856e-16
# permit : 7.466183e-16
# race : 7.352702e-16
# repeated : 7.3164964e-16
# expected : 6.6582655e-16
# materials : 6.481216e-16
# reference : 6.233971e-16
# same : 5.124502e-16
# vascular : 4.989836e-16
# mail : 4.301114e-16
# suggested : 4.2134362e-16
# there : 4.1968174e-16
# suggesting : 4.1454393e-16
# new : 4.0884626e-16
# date : 3.982921e-16
# moderately : 3.8782097e-16
# decreased : 3.5469322e-16
# adult : 3.536259e-16
# found : 3.5193563e-16
# others : 3.424415e-16
# national : 3.396807e-16
# data : 3.3557092e-16
# excess : 3.3065077e-16
# characterized : 3.2966716e-16
# significant : 2.8620026e-16
# three : 2.5766144e-16
# allison : 2.395995e-16
# descriptive : 2.1614245e-16
# category : 2.0033421e-16
# change : 1.9395812e-16
# associated : 1.8185265e-16
# person's : 1.6100684e-16
# known : 1.5417804e-16
# complete : 1.3142048e-16
# his : 1.1768688e-16
# scheduled : 1.0403238e-16
# evidence : 8.988564e-17
# review : 8.618995e-17
# sex : 7.44536e-17
# high : 7.2943936e-17
# gain : 6.9714134e-17
# lived : 6.914734e-17
# interval : 6.3637155e-17
# combined : 5.213287e-17
# measures : 4.478543e-17
# cancer : 4.3604363e-17
# design : 3.091328e-17
# part : 2.5313207e-17
# home : 2.5197022e-17
# observed : 2.5005038e-17
# optimal : 2.4765533e-17
# magnitude : 2.3144502e-17
# seen : 2.2474646e-17
# modified : 2.0274352e-17
# good : 1.9763039e-17
# former : 1.9076896e-17
# certain : 1.5073519e-17
# statistically : 1.457035e-17
# row : 1.3501458e-17
# linear : 1.3425243e-17
# values : 1.0193807e-17
# p : 8.66412e-18
# internal : 8.53559e-18
# leaving : 7.603622e-18
# adjust : 6.350665e-18
# lose : 6.201541e-18
# evident : 5.4235226e-18
# overlap : 5.0356857e-18
# distribution : 4.6756363e-18
# information : 4.263684e-18
# medicare : 3.988147e-18
# lists : 3.967026e-18
# cause : 3.0009521e-18
# it : 2.8634302e-18
# powerful : 2.1754929e-18
# mortality : 2.0484164e-18
# brief : 1.8106266e-18
# paper : 1.6666663e-18
# tested : 1.3139479e-18
# coding : 1.0140861e-18
# controlling : 1.0105334e-18
# telephone : 7.388089e-19
# subjects : 5.086439e-19
# has : 4.6515106e-19
# large : 2.873134e-19
# person : 2.7060596e-19
# dead : 2.608863e-19
# chose : 2.4898503e-19
# controlled : 2.4664815e-19
# some : 2.4528762e-19
# both : 2.0330095e-19
# needed : 1.6792566e-19
# institute : 1.5015998e-19
# improve : 1.1456386e-19
# females : 9.262423e-20
# people : 8.608566e-20
# variables : 8.0019656e-20
# factors : 6.87042e-20
# state : 5.585655e-20
# without : 5.092591e-20
# us : 5.068791e-20
# examined : 3.9792376e-20
# added : 3.435949e-20
# seven : 3.314002e-20
# sixth : 2.4966017e-20
# clinic : 2.3189008e-20
# then : 2.1545464e-20
# power : 1.424894e-20
# months : 1.082366e-20
# except : 1.9111164e-21
# well-known : 1.865201e-21
# fair : 6.3084947e-22
# below : 2.9081717e-23
#
# Prediction: some of them looks like et

# %% [markdown]
# 学習を試したい場合は、下記をアンコメントして実行してもよい。
# (実行時間が長いため、適宜 エポック数など調整すること)

# %%
# # 辞書ファイルの構築 
# #   学習済みモデルを作成するときに用いられた辞書ファイルがあるため必ずしも実行しなくてよい
# # build_dict()

# # 言語モデルオブジェクトの生成
# ln=Language()

# # 学習実行 + テストデータ評価, モデルファイル保存
# history = ln.train("./data_for_predict/trained_model")
